# %%
#-*-coding:utf-8-*-
from __future__ import print_function, division
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, multiply
from keras.layers import BatchNormalization, Activation, Embedding, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.models import Sequential
import util
import utils
import tensorflow.contrib.gan as tfgan
num_images_to_eval = 500
import torch.nn as nn
import tensorflow as tf
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.9)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

from torch.utils.data import Dataset
class MyDataset(Dataset):
    def __init__(self, imgs, transform=None):
        # super().__init__()
        self.imgs = imgs
        self.transform = transform

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, index):
        img = self.imgs[index]
        if self.transform is not None:
            img = self.transform(img)
        else:
            img = torch.from_numpy(img)
        return img


import math
import os
import numpy as np
import ot
import torch
import torch.nn.functional as F
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import torchvision.models as models

from scipy import linalg

from keras.datasets import mnist
import matplotlib.pyplot as plt

def giveName(iter):  # 7 digit name.
    ans = str(iter)
    return ans.zfill(7)

def make_dataset(dataset, dataroot, imageSize):
    """
    :param dataset: must be in 'cifar10 | lsun | imagenet | folder | lfw | fake'
    :return: pytorch dataset for DataLoader to utilize
    """
    if dataset in ['imagenet', 'folder', 'lfw']:
        print(os.getcwd() + dataroot)  # 函数的作用是用于返回当前工作目录
        # folder dataset
        # dataset = dset.ImageFolder(root=dataroot,
        dataset = dset.ImageFolder(root=os.getcwd() + dataroot,
                                   transform=transforms.Compose([
                                       transforms.Resize(imageSize),
                                       # transforms.CenterCrop(imageSize),
                                       transforms.ToTensor(),
                                       transforms.Normalize(
                                           (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                                   ]))
    elif dataset == 'lsun':
        dataset = dset.LSUN(db_path=dataroot, classes=['bedroom_train'],
                            transform=transforms.Compose([
                                transforms.Resize(imageSize),
                                transforms.CenterCrop(imageSize),
                                transforms.ToTensor(),
                                transforms.Normalize(
                                    (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                            ]))
    elif dataset == 'cifar10':
        dataset = dset.CIFAR10(root=dataroot, download=True,
                               transform=transforms.Compose([
                                   transforms.Resize(imageSize),
                                   transforms.ToTensor(),
                                   transforms.Normalize(
                                       (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                               ]))
    elif dataset == 'celeba':
        dataset = dset.ImageFolder(root=dataroot,
                                   transform=transforms.Compose([
                                       transforms.CenterCrop(138),
                                       transforms.Resize(imageSize),
                                       transforms.ToTensor(),
                                       transforms.Normalize(
                                           (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                                   ]))
    else:
        raise Exception('--dataset must be in cifar10 | lsun | imagenet | folder | lfw | fake')
    assert dataset
    return dataset

MNIST_CLASSIFIER_FROZEN_GRAPH = './classify_mnist_graph_def.pb'
INPUT_TENSOR = 'inputs:0'
OUTPUT_TENSOR = 'logits:0'
# CONV_TENSOR = 'fc3/Relu:0'
CONV_TENSOR = 'fc4/BiasAdd:0'
class ConvNetFeatureSaver(object):
    def __init__(self, model='cnn', workers=4, batchSize=64):
        '''
        model: inception_v3, vgg13, vgg16, vgg19, resnet18, resnet34,
               resnet50, resnet101, or resnet152
        '''
        self.model = model
        self.batch_size = batchSize
        self.workers = workers
        if self.model.find('tfgan') >= 0:
            print('tfgan')

        elif self.model.find('vgg') >= 0:
            self.vgg = getattr(models, model)(pretrained=True).cuda().eval()
            self.trans = transforms.Compose([
                transforms.Resize(224),
                transforms.ToTensor(),
                transforms.Normalize((0.485, 0.456, 0.406),
                                     (0.229, 0.224, 0.225)),
            ])
        elif self.model.find('resnet') >= 0:
            resnet = getattr(models, model)(pretrained=True)
            resnet.cuda().eval()
            resnet_feature = nn.Sequential(resnet.conv1, resnet.bn1,
                                           resnet.relu,
                                           resnet.maxpool, resnet.layer1,
                                           resnet.layer2, resnet.layer3,
                                           resnet.layer4).cuda().eval()
            self.resnet = resnet
            self.resnet_feature = resnet_feature
            self.trans = transforms.Compose([
                transforms.Resize(224),
                transforms.ToTensor(),
                transforms.Normalize((0.485, 0.456, 0.406),
                                     (0.229, 0.224, 0.225)),
            ])
        elif self.model == 'inception' or self.model == 'inception_v3':
            inception = models.inception_v3(
                pretrained=True, transform_input=False).cuda().eval()
            inception_feature = nn.Sequential(inception.Conv2d_1a_3x3,
                                              inception.Conv2d_2a_3x3,
                                              inception.Conv2d_2b_3x3,
                                              nn.MaxPool2d(3, 2),
                                              inception.Conv2d_3b_1x1,
                                              inception.Conv2d_4a_3x3,
                                              nn.MaxPool2d(3, 2),
                                              inception.Mixed_5b,
                                              inception.Mixed_5c,
                                              inception.Mixed_5d,
                                              inception.Mixed_6a,
                                              inception.Mixed_6b,
                                              inception.Mixed_6c,
                                              inception.Mixed_6d,
                                              inception.Mixed_7a,
                                              inception.Mixed_7b,
                                              inception.Mixed_7c,
                                              ).cuda().eval()
            self.inception = inception
            self.inception_feature = inception_feature
            self.trans = transforms.Compose([
                transforms.Resize(299),
                transforms.ToTensor(),
                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            ])
        else:
            raise NotImplementedError

    def save(self, imgFolder, dataloader, save2disk=False):
        feature_pixl, feature_conv, feature_smax, feature_logit = [], [], [], []

        for img in dataloader:
            with torch.no_grad():
                input = img.cuda()
                if self.model == 'tfgan':
                    gen_imgs = np.array(img)
                    eval_images = tf.convert_to_tensor(gen_imgs)
                    flogit = util.mnist_logits(eval_images, MNIST_CLASSIFIER_FROZEN_GRAPH, INPUT_TENSOR, OUTPUT_TENSOR)
                    fconv = util.mnist_logits(eval_images, MNIST_CLASSIFIER_FROZEN_GRAPH, INPUT_TENSOR, CONV_TENSOR)
                    flogit,fconv=tf.Session().run([flogit,fconv])

                    flogit=torch.from_numpy(flogit)
                    fconv=torch.from_numpy(fconv)
                elif self.model == 'vgg' or self.model == 'vgg16':
                    print(self.vgg.features(input).shape)
                    fconv = self.vgg.features(input).view(input.size(0), -1)  # 相当于reshape
                    flogit = self.vgg.classifier(fconv)
                    # flogit = self.vgg.logitifier(fconv)
                elif self.model.find('resnet') >= 0:
                    fconv = self.resnet_feature(
                        input).mean(3).mean(2).squeeze()
                    flogit = self.resnet.fc(fconv)
                elif self.model == 'inception' or self.model == 'inception_v3':
                    fconv = self.inception_feature(
                        input).mean(3).mean(2).squeeze()
                    flogit = self.inception.fc(fconv)
                else:
                    raise NotImplementedError
                fsmax = F.softmax(flogit)
                '''
                总共有四个空间：1.feature_pixl 2.feature_conv 3.feature_logit 4.feature_smax
                '''
                feature_pixl.append(img)
                feature_conv.append(fconv.data.cpu())
                feature_logit.append(flogit.data.cpu())
                feature_smax.append(fsmax.data.cpu())

        feature_pixl = torch.cat(feature_pixl, 0).to('cpu')
        feature_conv = torch.cat(feature_conv, 0).to('cpu')
        feature_logit = torch.cat(feature_logit, 0).to('cpu')
        feature_smax = torch.cat(feature_smax, 0).to('cpu')

        return feature_pixl, feature_conv, feature_logit, feature_smax

    # return feature_pixl, feature_conv, feature_logit, feature_smax


def distance(X, Y, sqrt):
    nX = X.size(0)
    nY = Y.size(0)
    X = X.view(nX, -1)
    X2 = (X * X).sum(1).resize_(nX, 1)
    Y = Y.view(nY, -1)
    Y2 = (Y * Y).sum(1).resize_(nY, 1)

    M = torch.zeros(nX, nY)
    M.copy_(X2.expand(nX, nY) + Y2.expand(nY, nX).transpose(0, 1) -
            2 * torch.mm(X, Y.transpose(0, 1)))

    del X, X2, Y, Y2

    if sqrt:
        M = ((M + M.abs()) / 2).sqrt()

    return M


def wasserstein(M, sqrt):
    if sqrt:
        M = M.abs().sqrt()
    emd = ot.emd2([], [], M.numpy())

    return emd


class Score_knn:
    acc = 0
    acc_real = 0
    acc_fake = 0
    precision = 0
    recall = 0
    tp = 0
    fp = 0
    fn = 0
    ft = 0


def knn(Mxx, Mxy, Myy, k, sqrt):
    n0 = Mxx.size(0)
    n1 = Myy.size(0)
    label = torch.cat((torch.ones(n0), torch.zeros(n1)))
    M = torch.cat((torch.cat((Mxx, Mxy), 1), torch.cat(
        (Mxy.transpose(0, 1), Myy), 1)), 0)
    if sqrt:
        M = M.abs().sqrt()
    INFINITY = float('inf')
    val, idx = (M + torch.diag(INFINITY * torch.ones(n0 + n1))
                ).topk(k, 0, False)

    count = torch.zeros(n0 + n1)
    for i in range(0, k):
        count = count + label.index_select(0, idx[i])
    pred = torch.ge(count, (float(k) / 2) * torch.ones(n0 + n1)).float()

    s = Score_knn()
    s.tp = (pred * label).sum()
    s.fp = (pred * (1 - label)).sum()
    s.fn = ((1 - pred) * label).sum()
    s.tn = ((1 - pred) * (1 - label)).sum()
    s.precision = s.tp / (s.tp + s.fp + 1e-10)
    s.recall = s.tp / (s.tp + s.fn + 1e-10)
    s.acc_t = s.tp / (s.tp + s.fn)
    s.acc_f = s.tn / (s.tn + s.fp)
    s.acc = torch.eq(label, pred).float().mean()
    s.k = k

    return s


def mmd(Mxx, Mxy, Myy, sigma):
    scale = Mxx.mean()
    Mxx = torch.exp(-Mxx / (scale * 2 * sigma * sigma))
    Mxy = torch.exp(-Mxy / (scale * 2 * sigma * sigma))
    Myy = torch.exp(-Myy / (scale * 2 * sigma * sigma))
    mmd = math.sqrt(Mxx.mean() + Myy.mean() - 2 * Mxy.mean())

    return mmd


def entropy_score(X, Y, epsilons):
    Mxy = distance(X, Y, False)
    scores = []
    for epsilon in epsilons:
        scores.append(ent(Mxy.t(), epsilon))

    return scores


def ent(M, epsilon):
    n0 = M.size(0)
    n1 = M.size(1)
    neighbors = M.lt(epsilon).float()
    sums = neighbors.sum(0).repeat(n0, 1)
    sums[sums.eq(0)] = 1
    neighbors = neighbors.div(sums)
    probs = neighbors.sum(1) / n1
    rem = 1 - probs.sum()
    if rem < 0:
        rem = 0
    probs = torch.cat((probs, rem * torch.ones(1)), 0)
    e = {}
    e['probs'] = probs
    probs = probs[probs.gt(0)]
    e['ent'] = -probs.mul(probs.log()).sum()

    return e


eps = 1e-20


def inception_score(X):
    kl = X * ((X + eps).log() - (X.mean(0) + eps).log().expand_as(X))
    score = np.exp(kl.sum(1).mean())

    return score


def mode_score(X, Y):
    kl1 = X * ((X + eps).log() - (X.mean(0) + eps).log().expand_as(X))
    kl2 = X.mean(0) * ((X.mean(0) + eps).log() - (Y.mean(0) + eps).log())
    score = np.exp(kl1.sum(1).mean() - kl2.sum())

    return score


def fid(X, Y):
    m = X.mean(0)
    m_w = Y.mean(0)
    X_np = X.numpy()
    Y_np = Y.numpy()

    C = np.cov(X_np.transpose())
    C_w = np.cov(Y_np.transpose())
    C_C_w_sqrt = linalg.sqrtm(C.dot(C_w), True).real

    score = m.dot(m) + m_w.dot(m_w) - 2 * m_w.dot(m) + \
            np.trace(C + C_w - 2 * C_C_w_sqrt)
    return np.sqrt(score)


class Score:
    emd = 0
    mmd = 0
    knn = None


def compute_score(real, fake, k=1, sigma=1, sqrt=True):
    Mxx = distance(real, real, False)
    Mxy = distance(real, fake, False)
    Myy = distance(fake, fake, False)

    s = Score()
    s.emd = wasserstein(Mxy, sqrt)
    s.mmd = mmd(Mxx, Mxy, Myy, sigma)
    s.knn = knn(Mxx, Mxy, Myy, k, sqrt)

    return s


'''
参数说明：
dataset:真实数据集的path
imageSize:图片的大小
dataroot_real:真实数据所在的path
batchSize
saveFolder_r:真实数据的保存位置
conv_model:卷积模型
'''


def compute_score_raw(real_dataloader, fake_dataloader, batchSize, saveFolder_r, saveFolder_f, conv_model='resnet34',
                      workers=4):
    convnet_feature_saver = ConvNetFeatureSaver(model=conv_model,
                                                batchSize=batchSize, workers=workers)
    print(saveFolder_r)
    print(saveFolder_f)
    feature_r = convnet_feature_saver.save(saveFolder_r, real_dataloader, False)
    feature_f = convnet_feature_saver.save(saveFolder_f, fake_dataloader, False)

    # 4 feature spaces and 7 scores + incep + modescore + fid
    score = np.zeros(2 * 7 + 5)
    for i in range(0, 2):
        print('compute score in space: ' + str(i))
        Mxx = distance(feature_r[i], feature_r[i], False)
        Mxy = distance(feature_r[i], feature_f[i], False)
        Myy = distance(feature_f[i], feature_f[i], False)

        score[i * 7] = wasserstein(Mxy, True)
        score[i * 7 + 1] = mmd(Mxx, Mxy, Myy, 1)
        tmp = knn(Mxx, Mxy, Myy, 1, False)
        score[(i * 7 + 2):(i * 7 + 7)] = \
            tmp.acc, tmp.acc_t, tmp.acc_f, tmp.precision, tmp.recall


    score[14] = inception_score(feature_f[3])
    score[15] = mode_score(feature_r[3], feature_f[3])
    score[16] = fid(feature_r[3], feature_f[3])

    return score
labels_name=['w_pixl','mmd_pixl','acc_pixl','acc_t_pixl','acc_f_pixl','acc_precision_pixl','acc_recall_pixl',
             'w_conv','mmd_conv','acc_conv','acc_t_conv','acc_f_conv','acc_precision_conv','acc_recall_conv',
             'is','mode_score','fid' ,'tf_is','tf_fid']
if not os.path.isdir('saved_models_{}'.format('sgan')):
    os.mkdir('saved_models_{}'.format('sgan'))
f = open('saved_models_{}/log_collapse1.txt'.format('sgan'), mode='w')
import torch.utils.data as Data

from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, multiply, GaussianNoise
from keras.layers import BatchNormalization, Activation, Embedding, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras import losses
from keras.utils import to_categorical
import keras.backend as K

import matplotlib.pyplot as plt
import os
import numpy as np

class SGAN:
    def __init__(self):
        self.img_rows = 28
        self.img_cols = 28
        self.channels = 1
        self.img_shape = (self.img_rows, self.img_cols, self.channels)
        self.num_classes = 10
        self.latent_dim = 100
        self.x = []
        self.y = np.zeros((31, 1), dtype=np.int)
        self.y = list(self.y)
        for i in range(31):
            self.y[i] = []

        optimizer = Adam(0.0002, 0.5)

        # Build and compile the discriminator
        self.discriminator = self.build_discriminator()
        self.discriminator.compile(
            loss=['binary_crossentropy', 'categorical_crossentropy'],
            loss_weights=[0.5, 0.5],
            optimizer=optimizer,
            metrics=['accuracy']
        )

        # Build the generator
        self.generator = self.build_generator()

        # The generator takes noise as input and generates imgs
        noise = Input(shape=(100,))
        img = self.generator(noise)

        # For the combined model we will only train the generator
        self.discriminator.trainable = False

        # The valid takes generated images as input and determines validity
        valid, _ = self.discriminator(img)

        # The combined model  (stacked generator and discriminator)
        # Trains generator to fool discriminator
        self.combined = Model(noise, valid)
        self.combined.compile(loss=['binary_crossentropy'], optimizer=optimizer)

    def build_generator(self):

        model = Sequential()

        model.add(Dense(128 * 7 * 7, activation="relu", input_dim=self.latent_dim))
        model.add(Reshape((7, 7, 128)))
        model.add(BatchNormalization(momentum=0.8))
        model.add(UpSampling2D())
        model.add(Conv2D(128, kernel_size=3, padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(UpSampling2D())
        model.add(Conv2D(64, kernel_size=3, padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Conv2D(1, kernel_size=3, padding="same"))
        model.add(Activation("tanh"))

        model.summary()

        noise = Input(shape=(self.latent_dim,))
        img = model(noise)

        return Model(noise, img)

    def build_discriminator(self):

        model = Sequential()

        model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=self.img_shape, padding="same"))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))
        model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
        model.add(ZeroPadding2D(padding=((0,1),(0,1))))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))
        model.add(Flatten())

        model.summary()

        img = Input(shape=self.img_shape)

        features = model(img)
        valid = Dense(1, activation="sigmoid")(features)
        label = Dense(self.num_classes+1, activation="softmax")(features)

        return Model(img, [valid, label])

    def train(self, epochs, batch_size=128, sample_interval=50):

        # Load the dataset
        (X_train, y_train), (X_test, _) = mnist.load_data()

        # Rescale -1 to 1
        X_train = (X_train.astype(np.float32) - 127.5) / 127.5
        X_train = np.expand_dims(X_train, axis=3)
        X_test = (X_test.astype(np.float32) - 127.5) / 127.5
        # X_test = X_test / 127.5 - 1.
        X_test = np.expand_dims(X_test, axis=3)
        y_train = y_train.reshape(-1, 1)

        # Class weights:
        # To balance the difference in occurences of digit class labels.
        # 50% of labels that the discriminator trains on are 'fake'.
        # Weight = 1 / frequency
        half_batch = batch_size // 2
        cw1 = {0: 1, 1: 1}
        cw2 = {i: self.num_classes / half_batch for i in range(self.num_classes)}
        cw2[self.num_classes] = 1 / half_batch

        # Adversarial ground truths
        valid = np.ones((batch_size, 1))
        fake = np.zeros((batch_size, 1))

        nb_batches = int(X_train.shape[0] / batch_size)
        global_step = 0

        for epoch in range(epochs):

            for index in range(nb_batches):
                global_step += 1
                imgs = X_train[index * batch_size:(index + 1) * batch_size]
                # Sample noise and generate a batch of new images
                noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
                gen_imgs = self.generator.predict(noise)

                # One-hot encoding of labels
                labels = to_categorical(y_train[index * batch_size:(index + 1) * batch_size], num_classes=self.num_classes + 1)
                fake_labels = to_categorical(np.full((batch_size, 1), self.num_classes),
                                             num_classes=self.num_classes + 1)

                # Train the discriminator
                d_loss_real = self.discriminator.train_on_batch(imgs, [valid, labels], class_weight=[cw1, cw2])
                d_loss_fake = self.discriminator.train_on_batch(gen_imgs, [fake, fake_labels], class_weight=[cw1, cw2])
                d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

                # ---------------------
                #  Train Generator
                # ---------------------

                g_loss = self.combined.train_on_batch(noise, valid, class_weight=[cw1, cw2])

                # Plot the progress
                print("epoch:%d step:%d[D loss: %f, acc: %.2f%%, op_acc: %.2f%%] [G loss: %f]" % (
                epoch,global_step, d_loss[0], 100 * d_loss[3], 100 * d_loss[4], g_loss))

                # If at save interval => save generated image samples
                sampleSize = 10000
                # If at save interval => save generated image samples
                if global_step % sample_interval == 0:
                    s = self.metrics(global_step, X_test, sampleSize)
        for i in range(len(s)):
            self.y[i] = [float(j) / max(self.y[i]) for j in self.y[i]]#对值进行归一化处理

        for i in range(len(s)):
            font1={'size':8}

            plt.plot(self.x, self.y[i], label=labels_name[i])
            plt.legend(loc='lower right',prop=font1)
            plt.savefig('saved_models_sgan/{}.png'.format(labels_name[i]))
            plt.show()
            plt.close()

    def metrics(self, epoch, X_test, sampleSize):
        self.x.append(epoch)
        r, c = 10, sampleSize // 10
        noise = np.random.normal(0, 1, (r * c, 100))
#         sampled_labels = np.array([num for _ in range(r) for num in range(c)])
        gen_imgs = self.generator.predict([noise])
        x_dataset = MyDataset(X_test[:sampleSize])
        # print(x_dataset[0].shape)
        x_real_loader = Data.DataLoader(dataset=x_dataset, batch_size=2000, shuffle=True)
        x_fake_dataset = MyDataset(gen_imgs)
        x_fake_loader = Data.DataLoader(dataset=x_fake_dataset, batch_size=2000, shuffle=True)
        s = compute_score_raw(x_real_loader, x_fake_loader, 256, '/real/', './fake', conv_model='tfgan',
                              workers=int(1))
        real_images = tf.convert_to_tensor(X_test)  # real images
        # MNIST_CLASSIFIER_FROZEN_GRAPH = '.\classify_mnist_graph_def.pb'
        gen_imgs = np.array(gen_imgs)
        eval_images = tf.convert_to_tensor(gen_imgs)
        eval_score = utils.mnist_score(eval_images, MNIST_CLASSIFIER_FROZEN_GRAPH)  # IS score
        frechet_distance = utils.mnist_frechet_distance(real_images, eval_images, MNIST_CLASSIFIER_FROZEN_GRAPH)
        mnist_score, f_distance = sess.run([eval_score, frechet_distance])
        # print(mnist_score)
        # print(f_distance)
        # s[14]=mnist_score
        # s[16]=f_distance
        s[17] = mnist_score
        s[18] = f_distance
        print('IS socre: %f' % mnist_score)
        print('FID: %f' % f_distance)

        for i in range(len(s)):
            print(i, "=", s[i])
        for i in range(len(s)):
            self.y[i].append(s[i])
        f.writelines('\n')
        f.writelines('epoch:' + str(epoch))
        f.writelines('\n')
        f.writelines('%.8f' % (i) for i in s)
        f.writelines('\n')
        return s

if __name__ == '__main__':
    sgan = SGAN()
    sgan.train(epochs=20, batch_size=64, sample_interval=200)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 14, 14, 32)        320
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 8, 8, 64)          0
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 128)         73856
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 256)         295168
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4096)              0
# =================================================================
# Total params: 388,608
# Trainable params: 388,224
# Non-trainable params: 384
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 6272)              633472
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 128)       147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 28, 28, 64)        73792
# _________________________________________________________________
# activation_5 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 28, 28, 1)         577
# _________________________________________________________________
# activation_6 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 856,705
# Trainable params: 856,065
# Non-trainable params: 640
# _________________________________________________________________
# epoch:0 step:1[D loss: 0.621713, acc: 46.88%, op_acc: 10.94%] [G loss: 0.762490]
# epoch:0 step:2[D loss: 0.500837, acc: 65.62%, op_acc: 16.41%] [G loss: 0.911101]
# epoch:0 step:3[D loss: 0.459414, acc: 79.69%, op_acc: 11.72%] [G loss: 1.365978]
# epoch:0 step:4[D loss: 0.386613, acc: 92.97%, op_acc: 17.97%] [G loss: 1.449152]
# epoch:0 step:5[D loss: 0.357753, acc: 91.41%, op_acc: 18.75%] [G loss: 1.642269]
# epoch:0 step:6[D loss: 0.314335, acc: 95.31%, op_acc: 23.44%] [G loss: 1.794261]
# epoch:0 step:7[D loss: 0.320015, acc: 92.19%, op_acc: 24.22%] [G loss: 1.738642]
# epoch:0 step:8[D loss: 0.281738, acc: 98.44%, op_acc: 20.31%] [G loss: 2.015277]
# epoch:0 step:9[D loss: 0.283764, acc: 96.09%, op_acc: 26.56%] [G loss: 1.992086]
# epoch:0 step:10[D loss: 0.279197, acc: 95.31%, op_acc: 30.47%] [G loss: 2.213131]
# epoch:0 step:11[D loss: 0.278613, acc: 94.53%, op_acc: 35.94%] [G loss: 2.313026]
# epoch:0 step:12[D loss: 0.241694, acc: 97.66%, op_acc: 35.94%] [G loss: 2.355004]
# epoch:0 step:13[D loss: 0.225139, acc: 99.22%, op_acc: 39.84%] [G loss: 2.777653]
# epoch:0 step:14[D loss: 0.254233, acc: 96.88%, op_acc: 34.38%] [G loss: 2.777802]
# epoch:0 step:15[D loss: 0.215678, acc: 99.22%, op_acc: 47.66%] [G loss: 3.065720]
# epoch:0 step:16[D loss: 0.215908, acc: 97.66%, op_acc: 43.75%] [G loss: 3.167330]
# epoch:0 step:17[D loss: 0.201880, acc: 100.00%, op_acc: 49.22%] [G loss: 3.355107]
# epoch:0 step:18[D loss: 0.189190, acc: 100.00%, op_acc: 57.81%] [G loss: 3.547712]
# epoch:0 step:19[D loss: 0.193715, acc: 97.66%, op_acc: 53.91%] [G loss: 3.581359]
# epoch:0 step:20[D loss: 0.223438, acc: 96.09%, op_acc: 61.72%] [G loss: 3.338112]
# epoch:0 step:21[D loss: 0.166261, acc: 99.22%, op_acc: 60.94%] [G loss: 3.344483]
# epoch:0 step:22[D loss: 0.181345, acc: 100.00%, op_acc: 64.06%] [G loss: 3.182881]
# epoch:0 step:23[D loss: 0.177558, acc: 99.22%, op_acc: 58.59%] [G loss: 3.722671]
# epoch:0 step:24[D loss: 0.153320, acc: 100.00%, op_acc: 69.53%] [G loss: 3.895385]
# epoch:0 step:25[D loss: 0.142920, acc: 100.00%, op_acc: 67.19%] [G loss: 4.002171]
# epoch:0 step:26[D loss: 0.130312, acc: 100.00%, op_acc: 75.78%] [G loss: 3.636105]
# epoch:0 step:27[D loss: 0.100776, acc: 100.00%, op_acc: 81.25%] [G loss: 3.788864]
# epoch:0 step:28[D loss: 0.121107, acc: 100.00%, op_acc: 76.56%] [G loss: 3.902514]
# epoch:0 step:29[D loss: 0.122039, acc: 100.00%, op_acc: 76.56%] [G loss: 3.601945]
# epoch:0 step:30[D loss: 0.132308, acc: 98.44%, op_acc: 75.00%] [G loss: 3.636159]
# epoch:0 step:31[D loss: 0.150361, acc: 98.44%, op_acc: 67.97%] [G loss: 3.491206]
# epoch:0 step:32[D loss: 0.150108, acc: 99.22%, op_acc: 78.12%] [G loss: 3.155563]
# epoch:0 step:33[D loss: 0.115207, acc: 100.00%, op_acc: 74.22%] [G loss: 3.282283]
# epoch:0 step:34[D loss: 0.097750, acc: 100.00%, op_acc: 82.03%] [G loss: 3.470390]
# epoch:0 step:35[D loss: 0.089697, acc: 100.00%, op_acc: 85.16%] [G loss: 3.724771]
# epoch:0 step:36[D loss: 0.110400, acc: 100.00%, op_acc: 75.00%] [G loss: 3.890479]
# epoch:0 step:37[D loss: 0.099018, acc: 100.00%, op_acc: 79.69%] [G loss: 3.641938]
# epoch:0 step:38[D loss: 0.114014, acc: 100.00%, op_acc: 77.34%] [G loss: 3.251060]
# epoch:0 step:39[D loss: 0.105304, acc: 100.00%, op_acc: 81.25%] [G loss: 3.047619]
# epoch:0 step:40[D loss: 0.117378, acc: 100.00%, op_acc: 78.91%] [G loss: 3.311534]
# epoch:0 step:41[D loss: 0.108188, acc: 99.22%, op_acc: 78.12%] [G loss: 3.250461]
# epoch:0 step:42[D loss: 0.112557, acc: 100.00%, op_acc: 81.25%] [G loss: 2.733587]
# epoch:0 step:43[D loss: 0.114985, acc: 100.00%, op_acc: 73.44%] [G loss: 3.390765]
# epoch:0 step:44[D loss: 0.113361, acc: 99.22%, op_acc: 74.22%] [G loss: 3.438536]
# epoch:0 step:45[D loss: 0.136417, acc: 99.22%, op_acc: 76.56%] [G loss: 2.278420]
# epoch:0 step:46[D loss: 0.116654, acc: 97.66%, op_acc: 78.91%] [G loss: 3.393172]
# epoch:0 step:47[D loss: 0.079261, acc: 100.00%, op_acc: 89.06%] [G loss: 4.145950]
# epoch:0 step:48[D loss: 0.105613, acc: 100.00%, op_acc: 79.69%] [G loss: 3.319978]
# epoch:0 step:49[D loss: 0.083224, acc: 100.00%, op_acc: 82.03%] [G loss: 3.768378]
# epoch:0 step:50[D loss: 0.079447, acc: 100.00%, op_acc: 82.81%] [G loss: 3.457244]
# epoch:0 step:51[D loss: 0.095902, acc: 100.00%, op_acc: 78.12%] [G loss: 3.889683]
# epoch:0 step:52[D loss: 0.103093, acc: 99.22%, op_acc: 82.81%] [G loss: 2.823862]
# epoch:0 step:53[D loss: 0.133931, acc: 99.22%, op_acc: 71.09%] [G loss: 2.577082]
# epoch:0 step:54[D loss: 0.096199, acc: 100.00%, op_acc: 79.69%] [G loss: 3.686639]
# epoch:0 step:55[D loss: 0.125150, acc: 99.22%, op_acc: 74.22%] [G loss: 4.368643]
# epoch:0 step:56[D loss: 0.277337, acc: 85.94%, op_acc: 71.88%] [G loss: 2.245602]
# epoch:0 step:57[D loss: 0.333900, acc: 70.31%, op_acc: 53.12%] [G loss: 6.552959]
# epoch:0 step:58[D loss: 0.487335, acc: 62.50%, op_acc: 56.25%] [G loss: 2.043321]
# epoch:0 step:59[D loss: 0.188449, acc: 90.62%, op_acc: 62.50%] [G loss: 3.891193]
# epoch:0 step:60[D loss: 0.100144, acc: 100.00%, op_acc: 75.78%] [G loss: 5.043416]
# epoch:0 step:61[D loss: 0.151290, acc: 94.53%, op_acc: 78.91%] [G loss: 3.916006]
# epoch:0 step:62[D loss: 0.214859, acc: 87.50%, op_acc: 63.28%] [G loss: 4.415447]
# epoch:0 step:63[D loss: 0.137731, acc: 96.09%, op_acc: 80.47%] [G loss: 5.099477]
# epoch:0 step:64[D loss: 0.422251, acc: 60.94%, op_acc: 52.34%] [G loss: 5.143209]
# epoch:0 step:65[D loss: 0.238896, acc: 82.03%, op_acc: 67.97%] [G loss: 4.895387]
# epoch:0 step:66[D loss: 0.357108, acc: 74.22%, op_acc: 52.34%] [G loss: 4.848267]
# epoch:0 step:67[D loss: 0.362331, acc: 70.31%, op_acc: 59.38%] [G loss: 4.378873]
# epoch:0 step:68[D loss: 0.200017, acc: 86.72%, op_acc: 60.94%] [G loss: 4.953754]
# epoch:0 step:69[D loss: 0.205530, acc: 89.84%, op_acc: 64.84%] [G loss: 5.500581]
# epoch:0 step:70[D loss: 0.457775, acc: 62.50%, op_acc: 51.56%] [G loss: 3.834747]
# epoch:0 step:71[D loss: 0.551763, acc: 48.44%, op_acc: 43.75%] [G loss: 4.016183]
# epoch:0 step:72[D loss: 0.233041, acc: 78.91%, op_acc: 61.72%] [G loss: 4.204858]
# epoch:0 step:73[D loss: 0.516196, acc: 60.16%, op_acc: 54.69%] [G loss: 2.399414]
# epoch:0 step:74[D loss: 0.313956, acc: 79.69%, op_acc: 53.91%] [G loss: 2.280144]
# epoch:0 step:75[D loss: 0.184461, acc: 92.19%, op_acc: 64.06%] [G loss: 3.408355]
# epoch:0 step:76[D loss: 0.367358, acc: 70.31%, op_acc: 49.22%] [G loss: 2.721357]
# epoch:0 step:77[D loss: 0.240496, acc: 84.38%, op_acc: 50.78%] [G loss: 3.724323]
# epoch:0 step:78[D loss: 0.278088, acc: 77.34%, op_acc: 57.81%] [G loss: 3.181520]
# epoch:0 step:79[D loss: 0.444575, acc: 63.28%, op_acc: 48.44%] [G loss: 4.039494]
# epoch:0 step:80[D loss: 0.692531, acc: 39.06%, op_acc: 40.62%] [G loss: 3.157596]
# epoch:0 step:81[D loss: 0.400307, acc: 64.06%, op_acc: 50.00%] [G loss: 2.874795]
# epoch:0 step:82[D loss: 0.435891, acc: 60.94%, op_acc: 46.88%] [G loss: 3.222621]
# epoch:0 step:83[D loss: 0.467152, acc: 59.38%, op_acc: 46.09%] [G loss: 2.483943]
# epoch:0 step:84[D loss: 0.400609, acc: 71.09%, op_acc: 57.03%] [G loss: 2.692939]
# epoch:0 step:85[D loss: 0.510133, acc: 52.34%, op_acc: 43.75%] [G loss: 2.206582]
# epoch:0 step:86[D loss: 0.364029, acc: 71.88%, op_acc: 56.25%] [G loss: 2.971196]
# epoch:0 step:87[D loss: 0.347260, acc: 70.31%, op_acc: 55.47%] [G loss: 2.732697]
# epoch:0 step:88[D loss: 0.371715, acc: 71.88%, op_acc: 59.38%] [G loss: 1.652436]
# epoch:0 step:89[D loss: 0.351706, acc: 69.53%, op_acc: 52.34%] [G loss: 2.636652]
# epoch:0 step:90[D loss: 0.416629, acc: 67.97%, op_acc: 48.44%] [G loss: 2.403561]
# epoch:0 step:91[D loss: 0.328813, acc: 75.78%, op_acc: 55.47%] [G loss: 2.186377]
# epoch:0 step:92[D loss: 0.359950, acc: 77.34%, op_acc: 50.00%] [G loss: 2.480238]
# epoch:0 step:93[D loss: 0.367081, acc: 69.53%, op_acc: 54.69%] [G loss: 2.703280]
# epoch:0 step:94[D loss: 0.833307, acc: 25.00%, op_acc: 39.06%] [G loss: 1.645850]
# epoch:0 step:95[D loss: 0.467969, acc: 53.91%, op_acc: 53.91%] [G loss: 2.165160]
# epoch:0 step:96[D loss: 0.435214, acc: 57.81%, op_acc: 50.00%] [G loss: 1.958279]
# epoch:0 step:97[D loss: 0.619691, acc: 42.19%, op_acc: 43.75%] [G loss: 1.784948]
# epoch:0 step:98[D loss: 0.430554, acc: 60.94%, op_acc: 53.91%] [G loss: 2.302767]
# epoch:0 step:99[D loss: 0.487131, acc: 55.47%, op_acc: 49.22%] [G loss: 2.223964]
# epoch:0 step:100[D loss: 0.488330, acc: 57.03%, op_acc: 48.44%] [G loss: 1.888276]
# epoch:0 step:101[D loss: 0.448427, acc: 53.12%, op_acc: 56.25%] [G loss: 2.194314]
# epoch:0 step:102[D loss: 0.401131, acc: 66.41%, op_acc: 54.69%] [G loss: 2.201256]
# epoch:0 step:103[D loss: 0.403770, acc: 65.62%, op_acc: 51.56%] [G loss: 2.448633]
# epoch:0 step:104[D loss: 0.399825, acc: 65.62%, op_acc: 51.56%] [G loss: 2.040586]
# epoch:0 step:105[D loss: 0.300035, acc: 75.78%, op_acc: 54.69%] [G loss: 2.516768]
# epoch:0 step:106[D loss: 0.418316, acc: 66.41%, op_acc: 50.78%] [G loss: 2.545532]
# epoch:0 step:107[D loss: 0.346626, acc: 73.44%, op_acc: 42.19%] [G loss: 2.978932]
# epoch:0 step:108[D loss: 0.897968, acc: 25.78%, op_acc: 36.72%] [G loss: 1.687535]
# epoch:0 step:109[D loss: 0.597289, acc: 48.44%, op_acc: 37.50%] [G loss: 1.684450]
# epoch:0 step:110[D loss: 0.387699, acc: 70.31%, op_acc: 52.34%] [G loss: 2.151579]
# epoch:0 step:111[D loss: 0.421523, acc: 59.38%, op_acc: 47.66%] [G loss: 1.976311]
# epoch:0 step:112[D loss: 0.522497, acc: 50.78%, op_acc: 51.56%] [G loss: 1.749114]
# epoch:0 step:113[D loss: 0.445014, acc: 62.50%, op_acc: 50.78%] [G loss: 1.735481]
# epoch:0 step:114[D loss: 0.509411, acc: 52.34%, op_acc: 39.06%] [G loss: 1.633888]
# epoch:0 step:115[D loss: 0.388508, acc: 69.53%, op_acc: 46.88%] [G loss: 1.912853]
# epoch:0 step:116[D loss: 0.325709, acc: 75.00%, op_acc: 52.34%] [G loss: 2.146259]
# epoch:0 step:117[D loss: 0.379825, acc: 67.19%, op_acc: 46.88%] [G loss: 2.151392]
# epoch:0 step:118[D loss: 0.357316, acc: 74.22%, op_acc: 51.56%] [G loss: 2.015644]
# epoch:0 step:119[D loss: 0.378929, acc: 59.38%, op_acc: 51.56%] [G loss: 1.853192]
# epoch:0 step:120[D loss: 0.601005, acc: 42.97%, op_acc: 43.75%] [G loss: 1.435434]
# epoch:0 step:121[D loss: 0.418603, acc: 58.59%, op_acc: 47.66%] [G loss: 1.894177]
# epoch:0 step:122[D loss: 0.537402, acc: 48.44%, op_acc: 45.31%] [G loss: 1.521374]
# epoch:0 step:123[D loss: 0.444042, acc: 60.94%, op_acc: 49.22%] [G loss: 1.567544]
# epoch:0 step:124[D loss: 0.498849, acc: 56.25%, op_acc: 50.78%] [G loss: 1.515394]
# epoch:0 step:125[D loss: 0.440771, acc: 62.50%, op_acc: 52.34%] [G loss: 1.354898]
# epoch:0 step:126[D loss: 0.459474, acc: 58.59%, op_acc: 45.31%] [G loss: 1.593882]
# epoch:0 step:127[D loss: 0.438274, acc: 59.38%, op_acc: 42.19%] [G loss: 1.792752]
# epoch:0 step:128[D loss: 0.382399, acc: 62.50%, op_acc: 46.09%] [G loss: 1.746860]
# epoch:0 step:129[D loss: 0.454194, acc: 55.47%, op_acc: 50.00%] [G loss: 1.713389]
# epoch:0 step:130[D loss: 0.533787, acc: 44.53%, op_acc: 46.88%] [G loss: 1.409298]
# epoch:0 step:131[D loss: 0.455391, acc: 57.81%, op_acc: 46.09%] [G loss: 1.426497]
# epoch:0 step:132[D loss: 0.492529, acc: 53.12%, op_acc: 44.53%] [G loss: 1.328585]
# epoch:0 step:133[D loss: 0.521485, acc: 50.00%, op_acc: 48.44%] [G loss: 1.627970]
# epoch:0 step:134[D loss: 0.482496, acc: 50.78%, op_acc: 45.31%] [G loss: 1.434154]
# epoch:0 step:135[D loss: 0.435903, acc: 57.03%, op_acc: 47.66%] [G loss: 1.715513]
# epoch:0 step:136[D loss: 0.544035, acc: 45.31%, op_acc: 42.97%] [G loss: 1.492292]
# epoch:0 step:137[D loss: 0.641351, acc: 36.72%, op_acc: 40.62%] [G loss: 1.503952]
# epoch:0 step:138[D loss: 0.586308, acc: 38.28%, op_acc: 46.09%] [G loss: 1.493867]
# epoch:0 step:139[D loss: 0.578920, acc: 45.31%, op_acc: 33.59%] [G loss: 1.658507]
# epoch:0 step:140[D loss: 0.385045, acc: 63.28%, op_acc: 53.12%] [G loss: 1.635634]
# epoch:0 step:141[D loss: 0.315446, acc: 76.56%, op_acc: 57.81%] [G loss: 1.844589]
# epoch:0 step:142[D loss: 0.320664, acc: 71.09%, op_acc: 57.81%] [G loss: 1.983770]
# epoch:0 step:143[D loss: 0.243165, acc: 86.72%, op_acc: 59.38%] [G loss: 2.414172]
# epoch:0 step:144[D loss: 0.277695, acc: 78.91%, op_acc: 62.50%] [G loss: 1.892680]
# epoch:0 step:145[D loss: 0.370890, acc: 70.31%, op_acc: 47.66%] [G loss: 2.240474]
# epoch:0 step:146[D loss: 0.566102, acc: 48.44%, op_acc: 44.53%] [G loss: 1.761079]
# epoch:0 step:147[D loss: 0.522788, acc: 50.78%, op_acc: 46.09%] [G loss: 1.904544]
# epoch:0 step:148[D loss: 0.532734, acc: 40.62%, op_acc: 43.75%] [G loss: 1.449017]
# epoch:0 step:149[D loss: 0.597924, acc: 38.28%, op_acc: 47.66%] [G loss: 1.481935]
# epoch:0 step:150[D loss: 0.358003, acc: 72.66%, op_acc: 52.34%] [G loss: 1.894778]
# epoch:0 step:151[D loss: 0.402543, acc: 57.03%, op_acc: 49.22%] [G loss: 1.535232]
# epoch:0 step:152[D loss: 0.408970, acc: 60.16%, op_acc: 53.12%] [G loss: 1.406646]
# epoch:0 step:153[D loss: 0.410824, acc: 62.50%, op_acc: 46.88%] [G loss: 1.284475]
# epoch:0 step:154[D loss: 0.411559, acc: 54.69%, op_acc: 65.62%] [G loss: 1.474728]
# epoch:0 step:155[D loss: 0.370265, acc: 64.06%, op_acc: 57.81%] [G loss: 1.495493]
# epoch:0 step:156[D loss: 0.336291, acc: 73.44%, op_acc: 50.78%] [G loss: 1.612274]
# epoch:0 step:157[D loss: 0.468835, acc: 52.34%, op_acc: 49.22%] [G loss: 1.306736]
# epoch:0 step:158[D loss: 0.418833, acc: 60.94%, op_acc: 51.56%] [G loss: 1.332464]
# epoch:0 step:159[D loss: 0.361371, acc: 67.19%, op_acc: 50.00%] [G loss: 1.503947]
# epoch:0 step:160[D loss: 0.580658, acc: 46.88%, op_acc: 44.53%] [G loss: 1.336807]
# epoch:0 step:161[D loss: 0.497258, acc: 48.44%, op_acc: 35.16%] [G loss: 1.591837]
# epoch:0 step:162[D loss: 0.390086, acc: 60.16%, op_acc: 52.34%] [G loss: 1.673039]
# epoch:0 step:163[D loss: 0.412355, acc: 59.38%, op_acc: 52.34%] [G loss: 1.631598]
# epoch:0 step:164[D loss: 0.403187, acc: 64.84%, op_acc: 52.34%] [G loss: 1.485014]
# epoch:0 step:165[D loss: 0.418467, acc: 55.47%, op_acc: 47.66%] [G loss: 1.550685]
# epoch:0 step:166[D loss: 0.503717, acc: 45.31%, op_acc: 52.34%] [G loss: 1.291883]
# epoch:0 step:167[D loss: 0.413080, acc: 57.81%, op_acc: 52.34%] [G loss: 1.584776]
# epoch:0 step:168[D loss: 0.417160, acc: 64.06%, op_acc: 46.09%] [G loss: 1.494712]
# epoch:0 step:169[D loss: 0.424289, acc: 54.69%, op_acc: 53.91%] [G loss: 1.478476]
# epoch:0 step:170[D loss: 0.429896, acc: 57.03%, op_acc: 50.00%] [G loss: 1.450681]
# epoch:0 step:171[D loss: 0.454907, acc: 48.44%, op_acc: 53.12%] [G loss: 1.511735]
# epoch:0 step:172[D loss: 0.484820, acc: 46.88%, op_acc: 52.34%] [G loss: 1.287249]
# epoch:0 step:173[D loss: 0.388951, acc: 60.16%, op_acc: 56.25%] [G loss: 1.383696]
# epoch:0 step:174[D loss: 0.440612, acc: 57.81%, op_acc: 51.56%] [G loss: 1.387566]
# epoch:0 step:175[D loss: 0.373355, acc: 65.62%, op_acc: 53.91%] [G loss: 1.504288]
# epoch:0 step:176[D loss: 0.375284, acc: 66.41%, op_acc: 50.78%] [G loss: 1.561042]
# epoch:0 step:177[D loss: 0.386329, acc: 62.50%, op_acc: 51.56%] [G loss: 1.400360]
# epoch:0 step:178[D loss: 0.365455, acc: 65.62%, op_acc: 48.44%] [G loss: 1.403511]
# epoch:0 step:179[D loss: 0.406209, acc: 60.94%, op_acc: 57.03%] [G loss: 1.355205]
# epoch:0 step:180[D loss: 0.430813, acc: 53.91%, op_acc: 56.25%] [G loss: 1.292910]
# epoch:0 step:181[D loss: 0.407906, acc: 60.94%, op_acc: 50.78%] [G loss: 1.408946]
# epoch:0 step:182[D loss: 0.481347, acc: 50.00%, op_acc: 43.75%] [G loss: 1.184497]
# epoch:0 step:183[D loss: 0.426794, acc: 63.28%, op_acc: 42.19%] [G loss: 1.678318]
# epoch:0 step:184[D loss: 0.472094, acc: 53.12%, op_acc: 49.22%] [G loss: 1.417178]
# epoch:0 step:185[D loss: 0.413261, acc: 60.16%, op_acc: 51.56%] [G loss: 1.374115]
# epoch:0 step:186[D loss: 0.429925, acc: 58.59%, op_acc: 46.88%] [G loss: 1.480907]
# epoch:0 step:187[D loss: 0.456294, acc: 49.22%, op_acc: 49.22%] [G loss: 1.467361]
# epoch:0 step:188[D loss: 0.547292, acc: 43.75%, op_acc: 49.22%] [G loss: 1.194593]
# epoch:0 step:189[D loss: 0.433178, acc: 60.16%, op_acc: 42.97%] [G loss: 1.263318]
# epoch:0 step:190[D loss: 0.384771, acc: 63.28%, op_acc: 49.22%] [G loss: 1.338896]
# epoch:0 step:191[D loss: 0.462349, acc: 53.12%, op_acc: 48.44%] [G loss: 1.309095]
# epoch:0 step:192[D loss: 0.422616, acc: 59.38%, op_acc: 46.88%] [G loss: 1.460088]
# epoch:0 step:193[D loss: 0.422361, acc: 57.81%, op_acc: 49.22%] [G loss: 1.492882]
# epoch:0 step:194[D loss: 0.509504, acc: 45.31%, op_acc: 42.19%] [G loss: 1.315800]
# epoch:0 step:195[D loss: 0.510045, acc: 45.31%, op_acc: 39.84%] [G loss: 1.311693]
# epoch:0 step:196[D loss: 0.471240, acc: 50.78%, op_acc: 47.66%] [G loss: 1.575830]
# epoch:0 step:197[D loss: 0.419692, acc: 61.72%, op_acc: 46.09%] [G loss: 1.385261]
# epoch:0 step:198[D loss: 0.457543, acc: 52.34%, op_acc: 42.19%] [G loss: 1.431291]
# epoch:0 step:199[D loss: 0.446156, acc: 60.94%, op_acc: 46.09%] [G loss: 1.501255]
# epoch:0 step:200[D loss: 0.417718, acc: 61.72%, op_acc: 46.09%] [G loss: 1.537624]
# tfgan
# /real/
# ./fake
# /home/imi432_006/anaconda3/envs/tf/lib/python3.5/site-packages/ipykernel_launcher.py:208: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# compute score in space: 0
# compute score in space: 1
# IS socre: 3.881050
# FID: 94.686501
# 0 = 14.426339769601784
# 1 = 0.11384337815908041
# 2 = 0.9769499897956848
# 3 = 0.9761999845504761
# 4 = 0.9776999950408936
# 5 = 0.9776664972305298
# 6 = 0.9761999845504761
# 7 = 12.215856024932924
# 8 = 0.19714200518208785
# 9 = 0.9473000168800354
# 10 = 0.9433000087738037
# 11 = 0.9513000249862671
# 12 = 0.9509072303771973
# 13 = 0.9433000087738037
# 14 = 3.881060838699341
# 15 = 7.540395736694336
# 16 = 0.4307175278663635
# 17 = 3.881049871444702
# 18 = 94.6865005493164
# epoch:0 step:201[D loss: 0.410619, acc: 54.69%, op_acc: 50.00%] [G loss: 1.571716]
# epoch:0 step:202[D loss: 0.385344, acc: 60.16%, op_acc: 49.22%] [G loss: 1.546373]
# epoch:0 step:203[D loss: 0.585406, acc: 39.06%, op_acc: 42.97%] [G loss: 0.927653]
# epoch:0 step:204[D loss: 0.544488, acc: 45.31%, op_acc: 42.97%] [G loss: 1.192989]
# epoch:0 step:205[D loss: 0.461442, acc: 54.69%, op_acc: 44.53%] [G loss: 1.328605]
# epoch:0 step:206[D loss: 0.467913, acc: 48.44%, op_acc: 44.53%] [G loss: 1.280859]
# epoch:0 step:207[D loss: 0.434153, acc: 53.12%, op_acc: 49.22%] [G loss: 1.313891]
# epoch:0 step:208[D loss: 0.430792, acc: 62.50%, op_acc: 49.22%] [G loss: 1.455689]
# epoch:0 step:209[D loss: 0.441108, acc: 55.47%, op_acc: 47.66%] [G loss: 1.460894]
# epoch:0 step:210[D loss: 0.456776, acc: 50.00%, op_acc: 47.66%] [G loss: 1.422791]
# epoch:0 step:211[D loss: 0.385844, acc: 62.50%, op_acc: 52.34%] [G loss: 1.251068]
# epoch:0 step:212[D loss: 0.410549, acc: 60.16%, op_acc: 49.22%] [G loss: 1.271774]
# epoch:0 step:213[D loss: 0.411090, acc: 53.91%, op_acc: 56.25%] [G loss: 1.345436]
# epoch:0 step:214[D loss: 0.491362, acc: 52.34%, op_acc: 44.53%] [G loss: 1.280622]
# epoch:0 step:215[D loss: 0.362685, acc: 69.53%, op_acc: 46.09%] [G loss: 1.567238]
# epoch:0 step:216[D loss: 0.399925, acc: 60.94%, op_acc: 55.47%] [G loss: 1.369501]
# epoch:0 step:217[D loss: 0.378498, acc: 60.16%, op_acc: 54.69%] [G loss: 1.302006]
# epoch:0 step:218[D loss: 0.397649, acc: 63.28%, op_acc: 50.78%] [G loss: 1.489729]
# epoch:0 step:219[D loss: 0.425037, acc: 59.38%, op_acc: 46.88%] [G loss: 1.487209]
# epoch:0 step:220[D loss: 0.558635, acc: 46.09%, op_acc: 39.84%] [G loss: 1.201738]
# epoch:0 step:221[D loss: 0.456248, acc: 53.91%, op_acc: 43.75%] [G loss: 1.177395]
# epoch:0 step:222[D loss: 0.386717, acc: 66.41%, op_acc: 42.97%] [G loss: 1.384937]
# epoch:0 step:223[D loss: 0.434429, acc: 57.81%, op_acc: 44.53%] [G loss: 1.263552]
# epoch:0 step:224[D loss: 0.453733, acc: 57.03%, op_acc: 49.22%] [G loss: 1.054374]
# epoch:0 step:225[D loss: 0.448870, acc: 55.47%, op_acc: 43.75%] [G loss: 1.214863]
# epoch:0 step:226[D loss: 0.386390, acc: 60.16%, op_acc: 60.16%] [G loss: 1.420092]
# epoch:0 step:227[D loss: 0.445436, acc: 56.25%, op_acc: 53.91%] [G loss: 1.268643]
# epoch:0 step:228[D loss: 0.447891, acc: 53.12%, op_acc: 46.09%] [G loss: 1.225635]
# epoch:0 step:229[D loss: 0.431635, acc: 53.12%, op_acc: 50.00%] [G loss: 1.251428]
# epoch:0 step:230[D loss: 0.391768, acc: 60.16%, op_acc: 46.88%] [G loss: 1.419802]
# epoch:0 step:231[D loss: 0.378136, acc: 68.75%, op_acc: 46.88%] [G loss: 1.427849]
# epoch:0 step:232[D loss: 0.391709, acc: 68.75%, op_acc: 43.75%] [G loss: 1.489843]
# epoch:0 step:233[D loss: 0.470595, acc: 53.12%, op_acc: 47.66%] [G loss: 1.219715]
# epoch:0 step:234[D loss: 0.437643, acc: 58.59%, op_acc: 48.44%] [G loss: 1.330850]
# epoch:0 step:235[D loss: 0.431484, acc: 56.25%, op_acc: 52.34%] [G loss: 1.367485]
# epoch:0 step:236[D loss: 0.446174, acc: 49.22%, op_acc: 53.91%] [G loss: 1.387248]
# epoch:0 step:237[D loss: 0.433855, acc: 58.59%, op_acc: 48.44%] [G loss: 1.263488]
# epoch:0 step:238[D loss: 0.412958, acc: 58.59%, op_acc: 49.22%] [G loss: 1.354118]
# epoch:0 step:239[D loss: 0.414707, acc: 60.16%, op_acc: 53.91%] [G loss: 1.129086]
# epoch:0 step:240[D loss: 0.403089, acc: 60.94%, op_acc: 48.44%] [G loss: 1.324526]
# epoch:0 step:241[D loss: 0.379612, acc: 65.62%, op_acc: 53.12%] [G loss: 1.389140]
# epoch:0 step:242[D loss: 0.359407, acc: 67.19%, op_acc: 54.69%] [G loss: 1.499251]
# epoch:0 step:243[D loss: 0.440066, acc: 54.69%, op_acc: 50.00%] [G loss: 1.254310]
# epoch:0 step:244[D loss: 0.349868, acc: 70.31%, op_acc: 58.59%] [G loss: 1.197433]
# epoch:0 step:245[D loss: 0.376510, acc: 66.41%, op_acc: 51.56%] [G loss: 1.137548]
# epoch:0 step:246[D loss: 0.426527, acc: 61.72%, op_acc: 44.53%] [G loss: 1.407602]
# epoch:0 step:247[D loss: 0.421785, acc: 60.94%, op_acc: 48.44%] [G loss: 1.405429]
# epoch:0 step:248[D loss: 0.409967, acc: 58.59%, op_acc: 46.09%] [G loss: 1.252475]
# epoch:0 step:249[D loss: 0.447655, acc: 57.81%, op_acc: 48.44%] [G loss: 1.208206]
# epoch:0 step:250[D loss: 0.464079, acc: 52.34%, op_acc: 44.53%] [G loss: 1.142185]
# epoch:0 step:251[D loss: 0.423228, acc: 60.94%, op_acc: 38.28%] [G loss: 1.235796]
# epoch:0 step:252[D loss: 0.456672, acc: 47.66%, op_acc: 48.44%] [G loss: 1.315410]
# epoch:0 step:253[D loss: 0.379215, acc: 59.38%, op_acc: 48.44%] [G loss: 1.234581]
# epoch:0 step:254[D loss: 0.401195, acc: 55.47%, op_acc: 49.22%] [G loss: 1.118909]
# epoch:0 step:255[D loss: 0.449087, acc: 50.78%, op_acc: 50.78%] [G loss: 1.273762]
# epoch:0 step:256[D loss: 0.389059, acc: 60.16%, op_acc: 51.56%] [G loss: 1.226903]
# epoch:0 step:257[D loss: 0.378032, acc: 61.72%, op_acc: 53.12%] [G loss: 1.361202]
# epoch:0 step:258[D loss: 0.407926, acc: 59.38%, op_acc: 57.81%] [G loss: 1.101991]
# epoch:0 step:259[D loss: 0.351543, acc: 69.53%, op_acc: 54.69%] [G loss: 1.270788]
# epoch:0 step:260[D loss: 0.341207, acc: 67.97%, op_acc: 59.38%] [G loss: 1.339481]
# epoch:0 step:261[D loss: 0.461920, acc: 56.25%, op_acc: 53.91%] [G loss: 1.200244]
# epoch:0 step:262[D loss: 0.422027, acc: 57.03%, op_acc: 49.22%] [G loss: 1.302361]
# epoch:0 step:263[D loss: 0.460660, acc: 54.69%, op_acc: 53.12%] [G loss: 1.266698]
# epoch:0 step:264[D loss: 0.442832, acc: 56.25%, op_acc: 49.22%] [G loss: 1.365840]
# epoch:0 step:265[D loss: 0.391902, acc: 63.28%, op_acc: 46.88%] [G loss: 1.233491]
# epoch:0 step:266[D loss: 0.416604, acc: 57.81%, op_acc: 46.09%] [G loss: 1.143006]
# epoch:0 step:267[D loss: 0.408662, acc: 56.25%, op_acc: 51.56%] [G loss: 1.358028]
# epoch:0 step:268[D loss: 0.464076, acc: 50.78%, op_acc: 48.44%] [G loss: 1.264491]
# epoch:0 step:269[D loss: 0.461292, acc: 54.69%, op_acc: 51.56%] [G loss: 1.168761]
# epoch:0 step:270[D loss: 0.404092, acc: 59.38%, op_acc: 51.56%] [G loss: 1.435024]
# epoch:0 step:271[D loss: 0.385386, acc: 61.72%, op_acc: 51.56%] [G loss: 1.225848]
# epoch:0 step:272[D loss: 0.414013, acc: 60.16%, op_acc: 47.66%] [G loss: 1.202266]
# epoch:0 step:273[D loss: 0.396031, acc: 59.38%, op_acc: 50.78%] [G loss: 1.251983]
# epoch:0 step:274[D loss: 0.462886, acc: 55.47%, op_acc: 47.66%] [G loss: 1.264497]
# epoch:0 step:275[D loss: 0.477619, acc: 50.00%, op_acc: 46.88%] [G loss: 1.242631]
# epoch:0 step:276[D loss: 0.451040, acc: 53.12%, op_acc: 49.22%] [G loss: 1.408101]
# epoch:0 step:277[D loss: 0.408588, acc: 57.81%, op_acc: 49.22%] [G loss: 1.276524]
# epoch:0 step:278[D loss: 0.441611, acc: 53.91%, op_acc: 49.22%] [G loss: 1.083738]
# epoch:0 step:279[D loss: 0.396204, acc: 60.94%, op_acc: 47.66%] [G loss: 1.177515]
# epoch:0 step:280[D loss: 0.355018, acc: 68.75%, op_acc: 43.75%] [G loss: 1.486169]
# epoch:0 step:281[D loss: 0.452595, acc: 50.78%, op_acc: 52.34%] [G loss: 1.153081]
# epoch:0 step:282[D loss: 0.417907, acc: 55.47%, op_acc: 47.66%] [G loss: 1.293176]
# epoch:0 step:283[D loss: 0.409087, acc: 54.69%, op_acc: 52.34%] [G loss: 1.423021]
# epoch:0 step:284[D loss: 0.377089, acc: 64.84%, op_acc: 51.56%] [G loss: 1.306617]
# epoch:0 step:285[D loss: 0.366433, acc: 63.28%, op_acc: 55.47%] [G loss: 1.442830]
# epoch:0 step:286[D loss: 0.388805, acc: 60.16%, op_acc: 56.25%] [G loss: 1.184947]
# epoch:0 step:287[D loss: 0.418275, acc: 60.94%, op_acc: 58.59%] [G loss: 1.353223]
# epoch:0 step:288[D loss: 0.420063, acc: 60.16%, op_acc: 52.34%] [G loss: 1.363231]
# epoch:0 step:289[D loss: 0.410531, acc: 59.38%, op_acc: 53.91%] [G loss: 1.173561]
# epoch:0 step:290[D loss: 0.367486, acc: 63.28%, op_acc: 52.34%] [G loss: 1.335267]
# epoch:0 step:291[D loss: 0.430976, acc: 56.25%, op_acc: 50.78%] [G loss: 1.395408]
# epoch:0 step:292[D loss: 0.381988, acc: 64.06%, op_acc: 55.47%] [G loss: 1.314157]
# epoch:0 step:293[D loss: 0.393063, acc: 57.81%, op_acc: 53.91%] [G loss: 1.157192]
# epoch:0 step:294[D loss: 0.368810, acc: 62.50%, op_acc: 53.12%] [G loss: 1.380472]
# epoch:0 step:295[D loss: 0.428902, acc: 53.12%, op_acc: 50.78%] [G loss: 1.194724]
# epoch:0 step:296[D loss: 0.394484, acc: 58.59%, op_acc: 49.22%] [G loss: 1.301651]
# epoch:0 step:297[D loss: 0.393138, acc: 64.06%, op_acc: 47.66%] [G loss: 1.330231]
# epoch:0 step:298[D loss: 0.327132, acc: 69.53%, op_acc: 57.03%] [G loss: 1.233467]
# epoch:0 step:299[D loss: 0.358344, acc: 67.97%, op_acc: 53.12%] [G loss: 1.168920]
# epoch:0 step:300[D loss: 0.366819, acc: 66.41%, op_acc: 53.91%] [G loss: 1.342025]
# epoch:0 step:301[D loss: 0.403937, acc: 60.16%, op_acc: 52.34%] [G loss: 1.223689]
# epoch:0 step:302[D loss: 0.372661, acc: 66.41%, op_acc: 56.25%] [G loss: 1.311444]
# epoch:0 step:303[D loss: 0.440880, acc: 56.25%, op_acc: 52.34%] [G loss: 1.380155]
# epoch:0 step:304[D loss: 0.372685, acc: 62.50%, op_acc: 50.78%] [G loss: 1.399844]
# epoch:0 step:305[D loss: 0.522782, acc: 38.28%, op_acc: 50.78%] [G loss: 1.212232]
# epoch:0 step:306[D loss: 0.395653, acc: 64.06%, op_acc: 49.22%] [G loss: 1.201965]
# epoch:0 step:307[D loss: 0.423837, acc: 53.12%, op_acc: 48.44%] [G loss: 1.188686]
# epoch:0 step:308[D loss: 0.374140, acc: 55.47%, op_acc: 57.81%] [G loss: 1.229852]
# epoch:0 step:309[D loss: 0.369774, acc: 64.84%, op_acc: 63.28%] [G loss: 1.154010]
# epoch:0 step:310[D loss: 0.366991, acc: 63.28%, op_acc: 57.03%] [G loss: 1.193845]
# epoch:0 step:311[D loss: 0.382477, acc: 64.06%, op_acc: 58.59%] [G loss: 1.491738]
# epoch:0 step:312[D loss: 0.362148, acc: 72.66%, op_acc: 55.47%] [G loss: 1.269203]
# epoch:0 step:313[D loss: 0.333298, acc: 70.31%, op_acc: 49.22%] [G loss: 1.461817]
# epoch:0 step:314[D loss: 0.330996, acc: 73.44%, op_acc: 53.12%] [G loss: 1.659512]
# epoch:0 step:315[D loss: 0.354541, acc: 66.41%, op_acc: 59.38%] [G loss: 1.504009]
# epoch:0 step:316[D loss: 0.543059, acc: 41.41%, op_acc: 49.22%] [G loss: 1.186019]
# epoch:0 step:317[D loss: 0.428600, acc: 50.00%, op_acc: 49.22%] [G loss: 1.172524]
# epoch:0 step:318[D loss: 0.415014, acc: 60.16%, op_acc: 52.34%] [G loss: 1.280552]
# epoch:0 step:319[D loss: 0.402414, acc: 54.69%, op_acc: 50.00%] [G loss: 1.460302]
# epoch:0 step:320[D loss: 0.403626, acc: 56.25%, op_acc: 54.69%] [G loss: 1.194380]
# epoch:0 step:321[D loss: 0.346882, acc: 64.84%, op_acc: 53.12%] [G loss: 1.325871]
# epoch:0 step:322[D loss: 0.395720, acc: 61.72%, op_acc: 53.91%] [G loss: 1.230993]
# epoch:0 step:323[D loss: 0.443713, acc: 51.56%, op_acc: 48.44%] [G loss: 1.046013]
# epoch:0 step:324[D loss: 0.419235, acc: 55.47%, op_acc: 55.47%] [G loss: 1.353034]
# epoch:0 step:325[D loss: 0.341257, acc: 71.09%, op_acc: 53.91%] [G loss: 1.280062]
# epoch:0 step:326[D loss: 0.444103, acc: 56.25%, op_acc: 54.69%] [G loss: 1.268086]
# epoch:0 step:327[D loss: 0.384540, acc: 64.84%, op_acc: 54.69%] [G loss: 1.159928]
# epoch:0 step:328[D loss: 0.412291, acc: 57.81%, op_acc: 50.78%] [G loss: 1.335105]
# epoch:0 step:329[D loss: 0.452684, acc: 48.44%, op_acc: 50.78%] [G loss: 1.253588]
# epoch:0 step:330[D loss: 0.387018, acc: 60.16%, op_acc: 59.38%] [G loss: 1.365029]
# epoch:0 step:331[D loss: 0.323806, acc: 76.56%, op_acc: 60.94%] [G loss: 1.263219]
# epoch:0 step:332[D loss: 0.356256, acc: 67.19%, op_acc: 57.81%] [G loss: 1.200280]
# epoch:0 step:333[D loss: 0.393480, acc: 57.81%, op_acc: 50.00%] [G loss: 1.110353]
# epoch:0 step:334[D loss: 0.428591, acc: 51.56%, op_acc: 53.12%] [G loss: 1.138065]
# epoch:0 step:335[D loss: 0.383828, acc: 66.41%, op_acc: 48.44%] [G loss: 1.326076]
# epoch:0 step:336[D loss: 0.402518, acc: 54.69%, op_acc: 46.88%] [G loss: 1.281244]
# epoch:0 step:337[D loss: 0.374244, acc: 64.84%, op_acc: 50.00%] [G loss: 0.998771]
# epoch:0 step:338[D loss: 0.449131, acc: 53.12%, op_acc: 46.88%] [G loss: 1.093703]
# epoch:0 step:339[D loss: 0.335537, acc: 68.75%, op_acc: 53.12%] [G loss: 1.208379]
# epoch:0 step:340[D loss: 0.380176, acc: 64.84%, op_acc: 50.78%] [G loss: 1.265751]
# epoch:0 step:341[D loss: 0.362991, acc: 60.16%, op_acc: 57.03%] [G loss: 1.243260]
# epoch:0 step:342[D loss: 0.375388, acc: 54.69%, op_acc: 58.59%] [G loss: 1.124023]
# epoch:0 step:343[D loss: 0.375485, acc: 58.59%, op_acc: 54.69%] [G loss: 1.123380]
# epoch:0 step:344[D loss: 0.349067, acc: 65.62%, op_acc: 57.03%] [G loss: 1.288960]
# epoch:0 step:345[D loss: 0.381929, acc: 54.69%, op_acc: 60.16%] [G loss: 1.329215]
# epoch:0 step:346[D loss: 0.450225, acc: 56.25%, op_acc: 49.22%] [G loss: 1.158731]
# epoch:0 step:347[D loss: 0.331438, acc: 67.19%, op_acc: 57.03%] [G loss: 1.417076]
# epoch:0 step:348[D loss: 0.390125, acc: 60.94%, op_acc: 57.03%] [G loss: 1.221940]
# epoch:0 step:349[D loss: 0.437595, acc: 57.03%, op_acc: 53.12%] [G loss: 1.105222]
# epoch:0 step:350[D loss: 0.351502, acc: 64.84%, op_acc: 64.06%] [G loss: 1.298378]
# epoch:0 step:351[D loss: 0.350030, acc: 66.41%, op_acc: 55.47%] [G loss: 1.237098]
# epoch:0 step:352[D loss: 0.454326, acc: 52.34%, op_acc: 44.53%] [G loss: 1.206042]
# epoch:0 step:353[D loss: 0.424660, acc: 60.94%, op_acc: 44.53%] [G loss: 1.179205]
# epoch:0 step:354[D loss: 0.383383, acc: 67.97%, op_acc: 47.66%] [G loss: 1.337828]
# epoch:0 step:355[D loss: 0.422016, acc: 51.56%, op_acc: 47.66%] [G loss: 1.213516]
# epoch:0 step:356[D loss: 0.453208, acc: 51.56%, op_acc: 46.88%] [G loss: 1.287761]
# epoch:0 step:357[D loss: 0.426494, acc: 57.03%, op_acc: 45.31%] [G loss: 1.165328]
# epoch:0 step:358[D loss: 0.346406, acc: 67.19%, op_acc: 57.03%] [G loss: 1.335219]
# epoch:0 step:359[D loss: 0.368772, acc: 67.19%, op_acc: 52.34%] [G loss: 1.259463]
# epoch:0 step:360[D loss: 0.375858, acc: 62.50%, op_acc: 52.34%] [G loss: 1.418010]
# epoch:0 step:361[D loss: 0.405825, acc: 61.72%, op_acc: 54.69%] [G loss: 1.214681]
# epoch:0 step:362[D loss: 0.371117, acc: 65.62%, op_acc: 57.81%] [G loss: 1.383346]
# epoch:0 step:363[D loss: 0.413103, acc: 55.47%, op_acc: 51.56%] [G loss: 1.296221]
# epoch:0 step:364[D loss: 0.387031, acc: 61.72%, op_acc: 54.69%] [G loss: 1.205366]
# epoch:0 step:365[D loss: 0.397304, acc: 58.59%, op_acc: 60.94%] [G loss: 1.182288]
# epoch:0 step:366[D loss: 0.366011, acc: 67.97%, op_acc: 55.47%] [G loss: 1.288738]
# epoch:0 step:367[D loss: 0.347903, acc: 65.62%, op_acc: 55.47%] [G loss: 1.249441]
# epoch:0 step:368[D loss: 0.367257, acc: 64.84%, op_acc: 59.38%] [G loss: 1.180793]
# epoch:0 step:369[D loss: 0.373470, acc: 61.72%, op_acc: 54.69%] [G loss: 1.403955]
# epoch:0 step:370[D loss: 0.348625, acc: 69.53%, op_acc: 56.25%] [G loss: 1.331865]
# epoch:0 step:371[D loss: 0.423074, acc: 64.84%, op_acc: 46.88%] [G loss: 1.269790]
# epoch:0 step:372[D loss: 0.350805, acc: 65.62%, op_acc: 58.59%] [G loss: 1.444859]
# epoch:0 step:373[D loss: 0.456944, acc: 52.34%, op_acc: 46.88%] [G loss: 1.244058]
# epoch:0 step:374[D loss: 0.414206, acc: 55.47%, op_acc: 51.56%] [G loss: 1.168042]
# epoch:0 step:375[D loss: 0.430372, acc: 56.25%, op_acc: 53.12%] [G loss: 1.238408]
# epoch:0 step:376[D loss: 0.475923, acc: 46.88%, op_acc: 53.91%] [G loss: 1.185258]
# epoch:0 step:377[D loss: 0.386331, acc: 58.59%, op_acc: 54.69%] [G loss: 1.267138]
# epoch:0 step:378[D loss: 0.354864, acc: 62.50%, op_acc: 60.94%] [G loss: 1.441474]
# epoch:0 step:379[D loss: 0.388572, acc: 61.72%, op_acc: 54.69%] [G loss: 1.302119]
# epoch:0 step:380[D loss: 0.392816, acc: 64.84%, op_acc: 53.91%] [G loss: 1.244647]
# epoch:0 step:381[D loss: 0.339786, acc: 65.62%, op_acc: 58.59%] [G loss: 1.217905]
# epoch:0 step:382[D loss: 0.381681, acc: 65.62%, op_acc: 60.94%] [G loss: 1.140510]
# epoch:0 step:383[D loss: 0.372795, acc: 65.62%, op_acc: 56.25%] [G loss: 1.310544]
# epoch:0 step:384[D loss: 0.404535, acc: 57.03%, op_acc: 57.81%] [G loss: 1.326293]
# epoch:0 step:385[D loss: 0.426583, acc: 57.81%, op_acc: 53.12%] [G loss: 1.242398]
# epoch:0 step:386[D loss: 0.401849, acc: 53.12%, op_acc: 52.34%] [G loss: 1.062972]
# epoch:0 step:387[D loss: 0.412363, acc: 55.47%, op_acc: 46.09%] [G loss: 1.177667]
# epoch:0 step:388[D loss: 0.387210, acc: 64.84%, op_acc: 50.00%] [G loss: 1.373665]
# epoch:0 step:389[D loss: 0.396187, acc: 57.03%, op_acc: 53.12%] [G loss: 1.369145]
# epoch:0 step:390[D loss: 0.361991, acc: 67.97%, op_acc: 52.34%] [G loss: 1.340740]
# epoch:0 step:391[D loss: 0.403662, acc: 62.50%, op_acc: 44.53%] [G loss: 1.088020]
# epoch:0 step:392[D loss: 0.326171, acc: 68.75%, op_acc: 57.03%] [G loss: 1.458597]
# epoch:0 step:393[D loss: 0.370991, acc: 64.06%, op_acc: 55.47%] [G loss: 1.180254]
# epoch:0 step:394[D loss: 0.389028, acc: 60.16%, op_acc: 53.91%] [G loss: 1.399556]
# epoch:0 step:395[D loss: 0.355274, acc: 67.97%, op_acc: 50.00%] [G loss: 1.154554]
# epoch:0 step:396[D loss: 0.527939, acc: 38.28%, op_acc: 49.22%] [G loss: 1.188420]
# epoch:0 step:397[D loss: 0.366878, acc: 59.38%, op_acc: 50.78%] [G loss: 1.333126]
# epoch:0 step:398[D loss: 0.368967, acc: 60.16%, op_acc: 52.34%] [G loss: 1.136962]
# epoch:0 step:399[D loss: 0.308826, acc: 78.12%, op_acc: 53.12%] [G loss: 1.212312]
# epoch:0 step:400[D loss: 0.399025, acc: 57.03%, op_acc: 57.81%] [G loss: 1.420082]
# tfgan
# /real/
# ./fake
# compute score in space: 0
# compute score in space: 1
# IS socre: 4.847868
# FID: 60.176895
# 0 = 14.37464971966743
# 1 = 0.07976788225258648
# 2 = 0.9115999937057495
# 3 = 0.9836999773979187
# 4 = 0.8395000100135803
# 5 = 0.8597273230552673
# 6 = 0.9836999773979187
# 7 = 10.913909307932855
# 8 = 0.1585049986908468
# 9 = 0.9148499965667725
# 10 = 0.9197999835014343
# 11 = 0.9099000096321106
# 12 = 0.9107832312583923
# 13 = 0.9197999835014343
# 14 = 4.84789514541626
# 15 = 8.732800483703613
# 16 = 0.30355408787727356
# 17 = 4.847867965698242
# 18 = 60.17689514160156
# epoch:0 step:401[D loss: 0.409889, acc: 58.59%, op_acc: 53.12%] [G loss: 1.436884]
# epoch:0 step:402[D loss: 0.296649, acc: 78.12%, op_acc: 62.50%] [G loss: 1.411518]
# epoch:0 step:403[D loss: 0.380202, acc: 56.25%, op_acc: 57.81%] [G loss: 1.162487]
# epoch:0 step:404[D loss: 0.399817, acc: 55.47%, op_acc: 58.59%] [G loss: 1.413538]
# epoch:0 step:405[D loss: 0.347734, acc: 64.06%, op_acc: 56.25%] [G loss: 1.263312]
# epoch:0 step:406[D loss: 0.306761, acc: 74.22%, op_acc: 63.28%] [G loss: 1.341192]
# epoch:0 step:407[D loss: 0.358782, acc: 64.84%, op_acc: 57.03%] [G loss: 1.359478]
# epoch:0 step:408[D loss: 0.416283, acc: 59.38%, op_acc: 52.34%] [G loss: 1.161471]
# epoch:0 step:409[D loss: 0.317983, acc: 75.78%, op_acc: 57.81%] [G loss: 1.300408]
# epoch:0 step:410[D loss: 0.384672, acc: 58.59%, op_acc: 51.56%] [G loss: 1.048426]
# epoch:0 step:411[D loss: 0.419533, acc: 57.81%, op_acc: 55.47%] [G loss: 1.127308]
# epoch:0 step:412[D loss: 0.372615, acc: 64.06%, op_acc: 53.91%] [G loss: 1.186453]
# epoch:0 step:413[D loss: 0.378315, acc: 64.06%, op_acc: 47.66%] [G loss: 1.391974]
# epoch:0 step:414[D loss: 0.393030, acc: 57.81%, op_acc: 44.53%] [G loss: 1.307010]
# epoch:0 step:415[D loss: 0.364753, acc: 65.62%, op_acc: 50.78%] [G loss: 1.270095]
# epoch:0 step:416[D loss: 0.343645, acc: 66.41%, op_acc: 58.59%] [G loss: 1.129603]
# epoch:0 step:417[D loss: 0.413696, acc: 57.81%, op_acc: 57.81%] [G loss: 1.227259]
# epoch:0 step:418[D loss: 0.404284, acc: 64.84%, op_acc: 51.56%] [G loss: 1.241579]
# epoch:0 step:419[D loss: 0.386366, acc: 57.81%, op_acc: 53.12%] [G loss: 1.187958]
# epoch:0 step:420[D loss: 0.455767, acc: 43.75%, op_acc: 49.22%] [G loss: 1.147063]
# epoch:0 step:421[D loss: 0.344414, acc: 72.66%, op_acc: 54.69%] [G loss: 1.219087]
# epoch:0 step:422[D loss: 0.337169, acc: 66.41%, op_acc: 58.59%] [G loss: 1.367295]
# epoch:0 step:423[D loss: 0.345312, acc: 66.41%, op_acc: 60.94%] [G loss: 1.409408]
# epoch:0 step:424[D loss: 0.421253, acc: 52.34%, op_acc: 50.00%] [G loss: 1.255634]
# epoch:0 step:425[D loss: 0.394737, acc: 64.06%, op_acc: 53.91%] [G loss: 1.307812]
# epoch:0 step:426[D loss: 0.406764, acc: 63.28%, op_acc: 51.56%] [G loss: 1.409543]
# epoch:0 step:427[D loss: 0.355408, acc: 67.97%, op_acc: 64.84%] [G loss: 1.282453]
# epoch:0 step:428[D loss: 0.376383, acc: 61.72%, op_acc: 57.03%] [G loss: 1.226730]
# epoch:0 step:429[D loss: 0.322463, acc: 74.22%, op_acc: 54.69%] [G loss: 1.437250]
# epoch:0 step:430[D loss: 0.356383, acc: 66.41%, op_acc: 57.03%] [G loss: 1.413461]
# epoch:0 step:431[D loss: 0.342540, acc: 71.88%, op_acc: 53.12%] [G loss: 1.446481]
# epoch:0 step:432[D loss: 0.406408, acc: 59.38%, op_acc: 53.12%] [G loss: 1.053111]
# epoch:0 step:433[D loss: 0.393894, acc: 57.03%, op_acc: 53.12%] [G loss: 1.284607]
# epoch:0 step:434[D loss: 0.369004, acc: 63.28%, op_acc: 51.56%] [G loss: 1.345055]
# epoch:0 step:435[D loss: 0.364463, acc: 67.97%, op_acc: 54.69%] [G loss: 1.347823]
# epoch:0 step:436[D loss: 0.340734, acc: 70.31%, op_acc: 52.34%] [G loss: 1.378172]
# epoch:0 step:437[D loss: 0.387875, acc: 56.25%, op_acc: 57.81%] [G loss: 0.999576]
# epoch:0 step:438[D loss: 0.360640, acc: 60.94%, op_acc: 64.06%] [G loss: 1.231320]
# epoch:0 step:439[D loss: 0.377213, acc: 63.28%, op_acc: 57.03%] [G loss: 1.207933]
# epoch:0 step:440[D loss: 0.444093, acc: 52.34%, op_acc: 56.25%] [G loss: 1.063228]
# epoch:0 step:441[D loss: 0.389268, acc: 65.62%, op_acc: 53.12%] [G loss: 1.062665]
# epoch:0 step:442[D loss: 0.358962, acc: 60.94%, op_acc: 60.16%] [G loss: 1.262419]
# epoch:0 step:443[D loss: 0.373588, acc: 57.03%, op_acc: 57.03%] [G loss: 1.183575]
# epoch:0 step:444[D loss: 0.438103, acc: 53.91%, op_acc: 52.34%] [G loss: 1.057745]
# epoch:0 step:445[D loss: 0.376956, acc: 63.28%, op_acc: 54.69%] [G loss: 1.020926]
# epoch:0 step:446[D loss: 0.367225, acc: 61.72%, op_acc: 55.47%] [G loss: 1.146598]
# epoch:0 step:447[D loss: 0.337292, acc: 64.84%, op_acc: 60.16%] [G loss: 1.250979]
# epoch:0 step:448[D loss: 0.374094, acc: 65.62%, op_acc: 48.44%] [G loss: 1.186838]
# epoch:0 step:449[D loss: 0.338841, acc: 71.88%, op_acc: 59.38%] [G loss: 1.237852]
# epoch:0 step:450[D loss: 0.310299, acc: 72.66%, op_acc: 59.38%] [G loss: 1.363702]
# epoch:0 step:451[D loss: 0.317015, acc: 70.31%, op_acc: 59.38%] [G loss: 1.436993]
# epoch:0 step:452[D loss: 0.397316, acc: 58.59%, op_acc: 51.56%] [G loss: 1.344099]
# epoch:0 step:453[D loss: 0.390334, acc: 64.06%, op_acc: 50.78%] [G loss: 1.228645]
# epoch:0 step:454[D loss: 0.404227, acc: 60.94%, op_acc: 52.34%] [G loss: 1.293043]
# epoch:0 step:455[D loss: 0.379355, acc: 60.94%, op_acc: 46.88%] [G loss: 1.155919]
# epoch:0 step:456[D loss: 0.381361, acc: 60.94%, op_acc: 50.78%] [G loss: 1.258568]
# epoch:0 step:457[D loss: 0.395738, acc: 62.50%, op_acc: 50.00%] [G loss: 1.426478]
# epoch:0 step:458[D loss: 0.429656, acc: 58.59%, op_acc: 46.09%] [G loss: 1.256289]
# epoch:0 step:459[D loss: 0.373307, acc: 66.41%, op_acc: 51.56%] [G loss: 1.182469]
# epoch:0 step:460[D loss: 0.368142, acc: 65.62%, op_acc: 54.69%] [G loss: 1.385706]
# epoch:0 step:461[D loss: 0.352204, acc: 66.41%, op_acc: 60.94%] [G loss: 1.324343]
# epoch:0 step:462[D loss: 0.353063, acc: 63.28%, op_acc: 60.94%] [G loss: 1.379089]
# epoch:0 step:463[D loss: 0.398239, acc: 55.47%, op_acc: 53.12%] [G loss: 1.150577]
# epoch:0 step:464[D loss: 0.329865, acc: 70.31%, op_acc: 58.59%] [G loss: 1.272284]
# epoch:0 step:465[D loss: 0.389332, acc: 64.06%, op_acc: 51.56%] [G loss: 1.276572]
# epoch:0 step:466[D loss: 0.332534, acc: 70.31%, op_acc: 59.38%] [G loss: 1.427504]
# epoch:0 step:467[D loss: 0.333812, acc: 75.00%, op_acc: 49.22%] [G loss: 1.342984]
# epoch:0 step:468[D loss: 0.408516, acc: 62.50%, op_acc: 48.44%] [G loss: 1.269995]
# epoch:0 step:469[D loss: 0.326072, acc: 69.53%, op_acc: 54.69%] [G loss: 1.476860]
# epoch:0 step:470[D loss: 0.408999, acc: 54.69%, op_acc: 50.00%] [G loss: 1.292124]
# epoch:0 step:471[D loss: 0.423847, acc: 54.69%, op_acc: 49.22%] [G loss: 1.323132]
# epoch:0 step:472[D loss: 0.409442, acc: 58.59%, op_acc: 53.12%] [G loss: 1.490536]
# epoch:0 step:473[D loss: 0.346610, acc: 70.31%, op_acc: 53.12%] [G loss: 1.229012]
# epoch:0 step:474[D loss: 0.324051, acc: 67.97%, op_acc: 57.03%] [G loss: 1.226416]
# epoch:0 step:475[D loss: 0.379812, acc: 60.16%, op_acc: 53.91%] [G loss: 1.065850]
# epoch:0 step:476[D loss: 0.332998, acc: 69.53%, op_acc: 48.44%] [G loss: 1.174656]
# epoch:0 step:477[D loss: 0.424239, acc: 54.69%, op_acc: 50.00%] [G loss: 1.277630]
# epoch:0 step:478[D loss: 0.355184, acc: 67.97%, op_acc: 57.81%] [G loss: 1.337829]
# epoch:0 step:479[D loss: 0.451187, acc: 53.91%, op_acc: 53.91%] [G loss: 1.308094]
# epoch:0 step:480[D loss: 0.338739, acc: 67.19%, op_acc: 51.56%] [G loss: 1.266235]
# epoch:0 step:481[D loss: 0.353073, acc: 66.41%, op_acc: 57.03%] [G loss: 1.300327]
# epoch:0 step:482[D loss: 0.354745, acc: 61.72%, op_acc: 54.69%] [G loss: 1.383795]
# epoch:0 step:483[D loss: 0.389779, acc: 62.50%, op_acc: 50.00%] [G loss: 1.300911]
# epoch:0 step:484[D loss: 0.388922, acc: 59.38%, op_acc: 50.78%] [G loss: 1.436951]
# epoch:0 step:485[D loss: 0.350181, acc: 68.75%, op_acc: 52.34%] [G loss: 1.366852]
# epoch:0 step:486[D loss: 0.380615, acc: 58.59%, op_acc: 52.34%] [G loss: 1.163983]
# epoch:0 step:487[D loss: 0.339803, acc: 69.53%, op_acc: 51.56%] [G loss: 1.314787]
# epoch:0 step:488[D loss: 0.337002, acc: 71.09%, op_acc: 57.03%] [G loss: 1.382518]
# epoch:0 step:489[D loss: 0.388127, acc: 57.03%, op_acc: 57.81%] [G loss: 1.189262]
# epoch:0 step:490[D loss: 0.406200, acc: 60.94%, op_acc: 53.12%] [G loss: 1.410248]
# epoch:0 step:491[D loss: 0.405477, acc: 60.94%, op_acc: 53.12%] [G loss: 1.364733]
# epoch:0 step:492[D loss: 0.373033, acc: 59.38%, op_acc: 56.25%] [G loss: 1.243473]
# epoch:0 step:493[D loss: 0.381717, acc: 61.72%, op_acc: 61.72%] [G loss: 1.177600]
# epoch:0 step:494[D loss: 0.377490, acc: 69.53%, op_acc: 50.78%] [G loss: 1.313807]
# epoch:0 step:495[D loss: 0.400000, acc: 63.28%, op_acc: 53.91%] [G loss: 1.278711]
# epoch:0 step:496[D loss: 0.375094, acc: 68.75%, op_acc: 50.00%] [G loss: 1.274762]
# epoch:0 step:497[D loss: 0.350835, acc: 68.75%, op_acc: 50.78%] [G loss: 1.402631]
# epoch:0 step:498[D loss: 0.327046, acc: 70.31%, op_acc: 56.25%] [G loss: 1.503017]
# epoch:0 step:499[D loss: 0.350326, acc: 67.19%, op_acc: 53.91%] [G loss: 1.437093]
# epoch:0 step:500[D loss: 0.385467, acc: 65.62%, op_acc: 52.34%] [G loss: 1.295500]
# epoch:0 step:501[D loss: 0.405568, acc: 62.50%, op_acc: 54.69%] [G loss: 1.030732]
# epoch:0 step:502[D loss: 0.427809, acc: 57.81%, op_acc: 48.44%] [G loss: 1.172095]
# epoch:0 step:503[D loss: 0.359863, acc: 64.06%, op_acc: 53.12%] [G loss: 1.201348]
# epoch:0 step:504[D loss: 0.344458, acc: 61.72%, op_acc: 54.69%] [G loss: 1.307693]
# epoch:0 step:505[D loss: 0.399370, acc: 57.81%, op_acc: 54.69%] [G loss: 1.268415]
# epoch:0 step:506[D loss: 0.407103, acc: 60.94%, op_acc: 53.91%] [G loss: 1.349720]
# epoch:0 step:507[D loss: 0.445725, acc: 53.91%, op_acc: 50.78%] [G loss: 1.186789]
# epoch:0 step:508[D loss: 0.358122, acc: 68.75%, op_acc: 50.00%] [G loss: 1.397927]
# epoch:0 step:509[D loss: 0.412971, acc: 53.12%, op_acc: 52.34%] [G loss: 1.298788]
# ...
# epoch:19 step:18562[D loss: 0.394289, acc: 57.81%, op_acc: 52.34%] [G loss: 1.435576]
# epoch:19 step:18563[D loss: 0.421986, acc: 51.56%, op_acc: 58.59%] [G loss: 1.179260]
# epoch:19 step:18564[D loss: 0.478026, acc: 40.62%, op_acc: 53.12%] [G loss: 0.746806]
# epoch:19 step:18565[D loss: 0.392097, acc: 49.22%, op_acc: 51.56%] [G loss: 1.252274]
# epoch:19 step:18566[D loss: 0.344787, acc: 59.38%, op_acc: 60.16%] [G loss: 1.156415]
# epoch:19 step:18567[D loss: 0.283529, acc: 75.78%, op_acc: 60.94%] [G loss: 1.177105]
# epoch:19 step:18568[D loss: 0.406606, acc: 53.12%, op_acc: 50.78%] [G loss: 0.901589]
# epoch:19 step:18569[D loss: 0.399024, acc: 57.03%, op_acc: 51.56%] [G loss: 1.003353]
# epoch:19 step:18570[D loss: 0.245055, acc: 84.38%, op_acc: 53.91%] [G loss: 1.113731]
# epoch:19 step:18571[D loss: 0.284627, acc: 78.91%, op_acc: 56.25%] [G loss: 1.289116]
# epoch:19 step:18572[D loss: 0.191675, acc: 91.41%, op_acc: 65.62%] [G loss: 1.504662]
# epoch:19 step:18573[D loss: 0.281853, acc: 75.78%, op_acc: 55.47%] [G loss: 1.148602]
# epoch:19 step:18574[D loss: 0.397833, acc: 54.69%, op_acc: 53.12%] [G loss: 1.046393]
# epoch:19 step:18575[D loss: 0.498828, acc: 31.25%, op_acc: 52.34%] [G loss: 1.382731]
# epoch:19 step:18576[D loss: 0.328835, acc: 70.31%, op_acc: 57.81%] [G loss: 1.275983]
# epoch:19 step:18577[D loss: 0.250587, acc: 78.12%, op_acc: 55.47%] [G loss: 1.115209]
# epoch:19 step:18578[D loss: 0.144018, acc: 100.00%, op_acc: 64.06%] [G loss: 1.674080]
# epoch:19 step:18579[D loss: 0.361398, acc: 62.50%, op_acc: 52.34%] [G loss: 1.293300]
# epoch:19 step:18580[D loss: 0.235953, acc: 82.03%, op_acc: 68.75%] [G loss: 1.680510]
# epoch:19 step:18581[D loss: 0.402186, acc: 51.56%, op_acc: 55.47%] [G loss: 1.203876]
# epoch:19 step:18582[D loss: 0.410673, acc: 47.66%, op_acc: 56.25%] [G loss: 1.147633]
# epoch:19 step:18583[D loss: 0.368119, acc: 61.72%, op_acc: 53.91%] [G loss: 1.001279]
# epoch:19 step:18584[D loss: 0.277855, acc: 77.34%, op_acc: 56.25%] [G loss: 1.401756]
# epoch:19 step:18585[D loss: 0.336533, acc: 65.62%, op_acc: 56.25%] [G loss: 0.910270]
# epoch:19 step:18586[D loss: 0.417132, acc: 50.00%, op_acc: 51.56%] [G loss: 1.234751]
# epoch:19 step:18587[D loss: 0.388838, acc: 52.34%, op_acc: 54.69%] [G loss: 0.963290]
# epoch:19 step:18588[D loss: 0.422316, acc: 48.44%, op_acc: 55.47%] [G loss: 1.271820]
# epoch:19 step:18589[D loss: 0.252475, acc: 82.81%, op_acc: 54.69%] [G loss: 1.052084]
# epoch:19 step:18590[D loss: 0.403279, acc: 53.91%, op_acc: 51.56%] [G loss: 0.943845]
# epoch:19 step:18591[D loss: 0.382926, acc: 57.81%, op_acc: 51.56%] [G loss: 1.232517]
# epoch:19 step:18592[D loss: 0.315246, acc: 67.97%, op_acc: 56.25%] [G loss: 1.319255]
# epoch:19 step:18593[D loss: 0.319528, acc: 66.41%, op_acc: 52.34%] [G loss: 0.906656]
# epoch:19 step:18594[D loss: 0.210275, acc: 86.72%, op_acc: 59.38%] [G loss: 1.246060]
# epoch:19 step:18595[D loss: 0.207371, acc: 82.03%, op_acc: 57.81%] [G loss: 1.324521]
# epoch:19 step:18596[D loss: 0.217136, acc: 88.28%, op_acc: 66.41%] [G loss: 1.604462]
# epoch:19 step:18597[D loss: 0.259622, acc: 82.03%, op_acc: 60.16%] [G loss: 1.199626]
# epoch:19 step:18598[D loss: 0.341615, acc: 66.41%, op_acc: 59.38%] [G loss: 1.469883]
# epoch:19 step:18599[D loss: 0.268792, acc: 75.00%, op_acc: 57.81%] [G loss: 1.196970]
# epoch:19 step:18600[D loss: 0.366592, acc: 64.06%, op_acc: 55.47%] [G loss: 1.121310]
# tfgan
# /real/
# ./fake
# compute score in space: 0
# compute score in space: 1
# IS socre: 8.430841
# FID: 2.600299
# 0 = 11.586628848934154
# 1 = 0.05399317712419186
# 2 = 0.7162500023841858
# 3 = 0.7914000153541565
# 4 = 0.6410999894142151
# 5 = 0.6879944205284119
# 6 = 0.7914000153541565
# 7 = 5.418418625974649
# 8 = 0.03732078963676048
# 9 = 0.6767500042915344
# 10 = 0.7063999772071838
# 11 = 0.6470999717712402
# 12 = 0.6668554544448853
# 13 = 0.7063999772071838
# 14 = 8.430907249450684
# 15 = 9.649526596069336
# 16 = 0.06281383335590363
# 17 = 8.430841445922852
# 18 = 2.600299119949341
# epoch:19 step:18601[D loss: 0.383534, acc: 57.03%, op_acc: 54.69%] [G loss: 0.996583]
# epoch:19 step:18602[D loss: 0.303605, acc: 68.75%, op_acc: 58.59%] [G loss: 1.322518]
# epoch:19 step:18603[D loss: 0.427424, acc: 49.22%, op_acc: 53.12%] [G loss: 1.506985]
# epoch:19 step:18604[D loss: 0.391670, acc: 55.47%, op_acc: 50.78%] [G loss: 1.145100]
# epoch:19 step:18605[D loss: 0.352457, acc: 67.19%, op_acc: 53.91%] [G loss: 0.815222]
# epoch:19 step:18606[D loss: 0.416792, acc: 50.78%, op_acc: 53.12%] [G loss: 0.678325]
# epoch:19 step:18607[D loss: 0.248515, acc: 81.25%, op_acc: 64.06%] [G loss: 1.109460]
# epoch:19 step:18608[D loss: 0.314578, acc: 71.88%, op_acc: 59.38%] [G loss: 1.080403]
# epoch:19 step:18609[D loss: 0.199646, acc: 89.84%, op_acc: 64.06%] [G loss: 1.499763]
# epoch:19 step:18610[D loss: 0.308836, acc: 69.53%, op_acc: 55.47%] [G loss: 1.472356]
# epoch:19 step:18611[D loss: 0.372152, acc: 58.59%, op_acc: 53.91%] [G loss: 1.234709]
# epoch:19 step:18612[D loss: 0.342027, acc: 67.19%, op_acc: 54.69%] [G loss: 1.119470]
# epoch:19 step:18613[D loss: 0.240815, acc: 80.47%, op_acc: 59.38%] [G loss: 1.421513]
# epoch:19 step:18614[D loss: 0.414949, acc: 50.00%, op_acc: 57.03%] [G loss: 1.115229]
# epoch:19 step:18615[D loss: 0.371254, acc: 61.72%, op_acc: 55.47%] [G loss: 1.034529]
# epoch:19 step:18616[D loss: 0.322238, acc: 67.19%, op_acc: 61.72%] [G loss: 1.058645]
# epoch:19 step:18617[D loss: 0.254420, acc: 79.69%, op_acc: 59.38%] [G loss: 1.411086]
# epoch:19 step:18618[D loss: 0.223765, acc: 78.12%, op_acc: 56.25%] [G loss: 1.613220]
# epoch:19 step:18619[D loss: 0.230716, acc: 84.38%, op_acc: 59.38%] [G loss: 1.516192]
# epoch:19 step:18620[D loss: 0.294429, acc: 74.22%, op_acc: 66.41%] [G loss: 1.256533]
# epoch:19 step:18621[D loss: 0.322924, acc: 68.75%, op_acc: 58.59%] [G loss: 1.436591]
# epoch:19 step:18622[D loss: 0.328650, acc: 67.97%, op_acc: 57.03%] [G loss: 1.132591]
# epoch:19 step:18623[D loss: 0.418971, acc: 53.12%, op_acc: 57.03%] [G loss: 1.112296]
# epoch:19 step:18624[D loss: 0.294249, acc: 74.22%, op_acc: 55.47%] [G loss: 1.093528]
# epoch:19 step:18625[D loss: 0.377959, acc: 60.16%, op_acc: 50.00%] [G loss: 1.032980]
# epoch:19 step:18626[D loss: 0.280223, acc: 81.25%, op_acc: 53.91%] [G loss: 1.223487]
# epoch:19 step:18627[D loss: 0.299164, acc: 76.56%, op_acc: 53.12%] [G loss: 1.148919]
# epoch:19 step:18628[D loss: 0.262795, acc: 75.00%, op_acc: 60.94%] [G loss: 1.400738]
# epoch:19 step:18629[D loss: 0.315705, acc: 72.66%, op_acc: 57.81%] [G loss: 1.203803]
# epoch:19 step:18630[D loss: 0.449609, acc: 40.62%, op_acc: 51.56%] [G loss: 1.044759]
# epoch:19 step:18631[D loss: 0.394639, acc: 60.94%, op_acc: 54.69%] [G loss: 1.115877]
# epoch:19 step:18632[D loss: 0.438627, acc: 50.78%, op_acc: 54.69%] [G loss: 1.007649]
# epoch:19 step:18633[D loss: 0.285001, acc: 72.66%, op_acc: 55.47%] [G loss: 1.336427]
# epoch:19 step:18634[D loss: 0.136650, acc: 96.09%, op_acc: 73.44%] [G loss: 1.098143]
# epoch:19 step:18635[D loss: 0.221602, acc: 86.72%, op_acc: 57.03%] [G loss: 1.655254]
# epoch:19 step:18636[D loss: 0.241486, acc: 85.16%, op_acc: 56.25%] [G loss: 1.582609]
# epoch:19 step:18637[D loss: 0.400549, acc: 57.81%, op_acc: 60.94%] [G loss: 1.582793]
# epoch:19 step:18638[D loss: 0.397944, acc: 55.47%, op_acc: 54.69%] [G loss: 1.058272]
# epoch:19 step:18639[D loss: 0.447598, acc: 43.75%, op_acc: 51.56%] [G loss: 0.956973]
# epoch:19 step:18640[D loss: 0.343296, acc: 64.06%, op_acc: 53.91%] [G loss: 1.154920]
# epoch:19 step:18641[D loss: 0.419530, acc: 50.00%, op_acc: 53.91%] [G loss: 1.248164]
# epoch:19 step:18642[D loss: 0.409223, acc: 53.12%, op_acc: 54.69%] [G loss: 1.078615]
# epoch:19 step:18643[D loss: 0.256305, acc: 80.47%, op_acc: 61.72%] [G loss: 1.447173]
# epoch:19 step:18644[D loss: 0.253496, acc: 80.47%, op_acc: 60.94%] [G loss: 1.586551]
# epoch:19 step:18645[D loss: 0.363386, acc: 61.72%, op_acc: 53.91%] [G loss: 1.294360]
# epoch:19 step:18646[D loss: 0.383626, acc: 53.91%, op_acc: 55.47%] [G loss: 1.347096]
# epoch:19 step:18647[D loss: 0.487420, acc: 39.06%, op_acc: 50.78%] [G loss: 1.193213]
# epoch:19 step:18648[D loss: 0.300632, acc: 71.09%, op_acc: 62.50%] [G loss: 1.170639]
# epoch:19 step:18649[D loss: 0.328591, acc: 64.06%, op_acc: 57.03%] [G loss: 1.097892]
# epoch:19 step:18650[D loss: 0.297319, acc: 77.34%, op_acc: 57.81%] [G loss: 1.111864]
# epoch:19 step:18651[D loss: 0.303859, acc: 71.88%, op_acc: 55.47%] [G loss: 1.251244]
# epoch:19 step:18652[D loss: 0.235412, acc: 85.94%, op_acc: 59.38%] [G loss: 1.122720]
# epoch:19 step:18653[D loss: 0.190175, acc: 96.09%, op_acc: 62.50%] [G loss: 1.154742]
# epoch:19 step:18654[D loss: 0.229808, acc: 82.81%, op_acc: 60.94%] [G loss: 1.202124]
# epoch:19 step:18655[D loss: 0.207845, acc: 89.84%, op_acc: 64.84%] [G loss: 1.633520]
# epoch:19 step:18656[D loss: 0.208493, acc: 90.62%, op_acc: 61.72%] [G loss: 1.786159]
# epoch:19 step:18657[D loss: 0.186892, acc: 90.62%, op_acc: 63.28%] [G loss: 1.712236]
# epoch:19 step:18658[D loss: 0.211479, acc: 89.06%, op_acc: 67.97%] [G loss: 1.572402]
# epoch:19 step:18659[D loss: 0.396326, acc: 60.16%, op_acc: 55.47%] [G loss: 0.872193]
# epoch:19 step:18660[D loss: 0.302379, acc: 71.88%, op_acc: 60.16%] [G loss: 1.381942]
# epoch:19 step:18661[D loss: 0.620150, acc: 34.38%, op_acc: 44.53%] [G loss: 1.158323]
# epoch:19 step:18662[D loss: 0.393468, acc: 51.56%, op_acc: 51.56%] [G loss: 1.252859]
# epoch:19 step:18663[D loss: 0.268136, acc: 82.81%, op_acc: 55.47%] [G loss: 1.280084]
# epoch:19 step:18664[D loss: 0.388912, acc: 54.69%, op_acc: 53.12%] [G loss: 1.304116]
# epoch:19 step:18665[D loss: 0.362295, acc: 60.16%, op_acc: 53.91%] [G loss: 1.597087]
# epoch:19 step:18666[D loss: 0.311448, acc: 71.88%, op_acc: 56.25%] [G loss: 1.333927]
# epoch:19 step:18667[D loss: 0.344895, acc: 66.41%, op_acc: 57.81%] [G loss: 1.068577]
# epoch:19 step:18668[D loss: 0.326382, acc: 67.97%, op_acc: 53.91%] [G loss: 1.225830]
# epoch:19 step:18669[D loss: 0.322816, acc: 68.75%, op_acc: 57.03%] [G loss: 0.960614]
# epoch:19 step:18670[D loss: 0.403625, acc: 53.91%, op_acc: 52.34%] [G loss: 1.109854]
# epoch:19 step:18671[D loss: 0.328391, acc: 67.19%, op_acc: 57.03%] [G loss: 0.949703]
# epoch:19 step:18672[D loss: 0.319905, acc: 66.41%, op_acc: 55.47%] [G loss: 1.266830]
# epoch:19 step:18673[D loss: 0.327674, acc: 64.06%, op_acc: 54.69%] [G loss: 1.141732]
# epoch:19 step:18674[D loss: 0.306814, acc: 75.00%, op_acc: 59.38%] [G loss: 1.084931]
# epoch:19 step:18675[D loss: 0.325604, acc: 64.06%, op_acc: 60.94%] [G loss: 1.343628]
# epoch:19 step:18676[D loss: 0.396469, acc: 55.47%, op_acc: 52.34%] [G loss: 0.876845]
# epoch:19 step:18677[D loss: 0.350992, acc: 63.28%, op_acc: 51.56%] [G loss: 1.150854]
# epoch:19 step:18678[D loss: 0.276247, acc: 78.91%, op_acc: 60.16%] [G loss: 1.242147]
# epoch:19 step:18679[D loss: 0.330735, acc: 70.31%, op_acc: 56.25%] [G loss: 1.093634]
# epoch:19 step:18680[D loss: 0.393626, acc: 51.56%, op_acc: 53.91%] [G loss: 0.960289]
# epoch:19 step:18681[D loss: 0.243237, acc: 79.69%, op_acc: 55.47%] [G loss: 1.618665]
# epoch:19 step:18682[D loss: 0.321729, acc: 67.19%, op_acc: 55.47%] [G loss: 1.208197]
# epoch:19 step:18683[D loss: 0.425081, acc: 49.22%, op_acc: 58.59%] [G loss: 1.222575]
# epoch:19 step:18684[D loss: 0.325419, acc: 67.19%, op_acc: 57.03%] [G loss: 1.072009]
# epoch:19 step:18685[D loss: 0.366220, acc: 54.69%, op_acc: 54.69%] [G loss: 0.883200]
# epoch:19 step:18686[D loss: 0.345254, acc: 65.62%, op_acc: 57.03%] [G loss: 1.168136]
# epoch:19 step:18687[D loss: 0.347693, acc: 63.28%, op_acc: 53.91%] [G loss: 1.157043]
# epoch:19 step:18688[D loss: 0.232771, acc: 86.72%, op_acc: 60.94%] [G loss: 1.272029]
# epoch:19 step:18689[D loss: 0.311984, acc: 71.88%, op_acc: 55.47%] [G loss: 0.949324]
# epoch:19 step:18690[D loss: 0.276240, acc: 79.69%, op_acc: 60.16%] [G loss: 1.094222]
# epoch:19 step:18691[D loss: 0.317281, acc: 70.31%, op_acc: 60.94%] [G loss: 1.446797]
# epoch:19 step:18692[D loss: 0.269247, acc: 75.00%, op_acc: 55.47%] [G loss: 1.350878]
# epoch:19 step:18693[D loss: 0.325072, acc: 67.19%, op_acc: 57.81%] [G loss: 1.279274]
# epoch:19 step:18694[D loss: 0.369473, acc: 57.03%, op_acc: 54.69%] [G loss: 1.106674]
# epoch:19 step:18695[D loss: 0.321743, acc: 67.19%, op_acc: 65.62%] [G loss: 1.163849]
# epoch:19 step:18696[D loss: 0.265777, acc: 81.25%, op_acc: 62.50%] [G loss: 1.384893]
# epoch:19 step:18697[D loss: 0.254332, acc: 79.69%, op_acc: 58.59%] [G loss: 1.387951]
# epoch:19 step:18698[D loss: 0.253802, acc: 81.25%, op_acc: 62.50%] [G loss: 1.426597]
# epoch:19 step:18699[D loss: 0.234999, acc: 89.84%, op_acc: 65.62%] [G loss: 1.423345]
# epoch:19 step:18700[D loss: 0.240941, acc: 75.78%, op_acc: 53.91%] [G loss: 1.203282]
# epoch:19 step:18701[D loss: 0.156534, acc: 93.75%, op_acc: 61.72%] [G loss: 1.652552]
# epoch:19 step:18702[D loss: 0.176399, acc: 92.19%, op_acc: 67.19%] [G loss: 1.787235]
# epoch:19 step:18703[D loss: 0.155006, acc: 93.75%, op_acc: 64.06%] [G loss: 1.711886]
# epoch:19 step:18704[D loss: 0.258392, acc: 84.38%, op_acc: 63.28%] [G loss: 1.726130]
# epoch:19 step:18705[D loss: 0.377114, acc: 60.94%, op_acc: 57.81%] [G loss: 1.127617]
# epoch:19 step:18706[D loss: 0.463540, acc: 48.44%, op_acc: 53.91%] [G loss: 0.900909]
# epoch:19 step:18707[D loss: 0.406836, acc: 50.00%, op_acc: 60.94%] [G loss: 1.382784]
# epoch:19 step:18708[D loss: 0.383458, acc: 60.94%, op_acc: 56.25%] [G loss: 1.489926]
# epoch:19 step:18709[D loss: 0.331761, acc: 63.28%, op_acc: 55.47%] [G loss: 1.124436]
# epoch:19 step:18710[D loss: 0.405253, acc: 54.69%, op_acc: 53.91%] [G loss: 1.309897]
# epoch:19 step:18711[D loss: 0.325016, acc: 68.75%, op_acc: 57.81%] [G loss: 0.801492]
# epoch:19 step:18712[D loss: 0.310905, acc: 72.66%, op_acc: 54.69%] [G loss: 0.975249]
# epoch:19 step:18713[D loss: 0.344714, acc: 61.72%, op_acc: 56.25%] [G loss: 1.386416]
# epoch:19 step:18714[D loss: 0.161314, acc: 96.09%, op_acc: 61.72%] [G loss: 1.798039]
# epoch:19 step:18715[D loss: 0.094887, acc: 96.88%, op_acc: 72.66%] [G loss: 1.994903]
# epoch:19 step:18716[D loss: 0.474937, acc: 47.66%, op_acc: 59.38%] [G loss: 1.400911]
# epoch:19 step:18717[D loss: 0.335819, acc: 67.97%, op_acc: 56.25%] [G loss: 1.274156]
# epoch:19 step:18718[D loss: 0.458763, acc: 46.09%, op_acc: 51.56%] [G loss: 1.089322]
# epoch:19 step:18719[D loss: 0.285265, acc: 75.00%, op_acc: 60.16%] [G loss: 1.400683]
# epoch:19 step:18720[D loss: 0.455995, acc: 39.84%, op_acc: 51.56%] [G loss: 0.973349]
# epoch:19 step:18721[D loss: 0.254890, acc: 81.25%, op_acc: 60.16%] [G loss: 1.242730]
# epoch:19 step:18722[D loss: 0.224298, acc: 85.94%, op_acc: 61.72%] [G loss: 1.668760]
# epoch:19 step:18723[D loss: 0.286659, acc: 78.91%, op_acc: 60.16%] [G loss: 1.383967]
# epoch:19 step:18724[D loss: 0.257375, acc: 81.25%, op_acc: 63.28%] [G loss: 1.690499]
# epoch:19 step:18725[D loss: 0.256129, acc: 82.81%, op_acc: 63.28%] [G loss: 1.389403]
# epoch:19 step:18726[D loss: 0.278586, acc: 82.03%, op_acc: 60.16%] [G loss: 1.211058]
# epoch:19 step:18727[D loss: 0.238062, acc: 85.94%, op_acc: 63.28%] [G loss: 1.432735]
# epoch:19 step:18728[D loss: 0.229071, acc: 81.25%, op_acc: 63.28%] [G loss: 1.463100]
# epoch:19 step:18729[D loss: 0.231425, acc: 82.81%, op_acc: 64.84%] [G loss: 1.382114]
# epoch:19 step:18730[D loss: 0.208411, acc: 85.94%, op_acc: 58.59%] [G loss: 1.114085]
# epoch:19 step:18731[D loss: 0.529677, acc: 42.19%, op_acc: 53.12%] [G loss: 1.143772]
# epoch:19 step:18732[D loss: 0.183787, acc: 93.75%, op_acc: 63.28%] [G loss: 1.200513]
# epoch:19 step:18733[D loss: 0.372642, acc: 56.25%, op_acc: 63.28%] [G loss: 1.250580]
# epoch:19 step:18734[D loss: 0.293638, acc: 71.09%, op_acc: 64.84%] [G loss: 1.523236]
# epoch:19 step:18735[D loss: 0.348754, acc: 61.72%, op_acc: 58.59%] [G loss: 1.279254]
# epoch:19 step:18736[D loss: 0.323074, acc: 68.75%, op_acc: 56.25%] [G loss: 1.438909]
# epoch:19 step:18737[D loss: 0.216351, acc: 85.94%, op_acc: 58.59%] [G loss: 1.624718]
# epoch:19 step:18738[D loss: 0.325976, acc: 64.84%, op_acc: 60.94%] [G loss: 1.452339]
# epoch:19 step:18739[D loss: 0.220534, acc: 83.59%, op_acc: 64.06%] [G loss: 1.128149]
# epoch:19 step:18740[D loss: 0.149835, acc: 92.19%, op_acc: 63.28%] [G loss: 1.551698]
